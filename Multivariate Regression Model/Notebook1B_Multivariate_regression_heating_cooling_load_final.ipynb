# %% [markdown]
# ## Notebook 1B: Multivariate regression of energy consumption

# %% [markdown]
# **1. Prepare Problem**

# %%
# a) Load libraries
import pandas as pd
from pandas import set_option
from pandas import DataFrame

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import keras
from keras.callbacks import EarlyStopping
from scikeras.wrappers import KerasRegressor
from tensorflow.keras.models import Sequential
from keras.layers import BatchNormalization, Dropout, Dense

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import learning_curve
from sklearn.model_selection import cross_val_score

from pickle import dump

# %%
# b) Load dataset
# Load and view each file in the dataset
data = pd.read_csv('EPB_data.csv', header=0)
print(data.shape)
print(data.head(10))
print(data.dtypes)
# Out:
# (768, 8)
#    Relative Compactness  Surface Area  Roof Area  Overall Height  Orientation  \
# 0                  0.98         514.5     110.25             7.0            2
# 1                  0.98         514.5     110.25             7.0            3
# 2                  0.98         514.5     110.25             7.0            4
# 3                  0.98         514.5     110.25             7.0            5
# 4                  0.90         563.5     122.50             7.0            2
# 5                  0.90         563.5     122.50             7.0            3
# 6                  0.90         563.5     122.50             7.0            4
# 7                  0.90         563.5     122.50             7.0            5
# 8                  0.86         588.0     147.00             7.0            2
# 9                  0.86         588.0     147.00             7.0            3
#
#    Glazing Area  Glazing Area Distribution  Heating Load
# 0           0.0                          0         15.55
# 1           0.0                          0         15.55
# 2           0.0                          0         15.55
# 3           0.0                          0         15.55
# 4           0.0                          0         20.84
# 5           0.0                          0         21.46
# 6           0.0                          0         20.71
# 7           0.0                          0         19.68
# 8           0.0                          0         19.50
# 9           0.0                          0         19.95
# Relative Compactness         float64
# Surface Area                 float64
# Roof Area                    float64
# Overall Height               float64
# Orientation                    int64
# Glazing Area                 float64
# Glazing Area Distribution      int64
# Heating Load                 float64
# dtype: object

# %% [markdown]
# One of the approach in optimizing building energy efficiency is to minimize total energy consumption, which is the sum of heating and cooling.

# %%
# Define features and label
X = data.drop(columns=['Heating Load'], axis = 1)
y = data[['Heating Load']]
print(X.shape, y.shape)
# Out:
# (768, 7) (768, 1)

# %% [markdown]
# **2. Dataset summary**

# %%
# a) Descriptive statistics
set_option("display.precision", 3)
print(data.describe())
# Out:
#        Relative Compactness  Surface Area  Roof Area  Overall Height  \
# count               768.000       768.000    768.000         768.000
# mean                  0.764       671.708    176.604           5.250
# std                   0.106        88.086     45.166           1.751
# min                   0.620       514.500    110.250           3.500
# 25%                   0.682       606.375    140.875           3.500
# 50%                   0.750       673.750    183.750           5.250
# 75%                   0.830       741.125    220.500           7.000
# max                   0.980       808.500    220.500           7.000
#
#        Orientation  Glazing Area  Glazing Area Distribution  Heating Load
# count      768.000       768.000                    768.000       768.000
# mean         3.500         0.234                      2.812        22.307
# std          1.119         0.133                      1.551        10.090
# min          2.000         0.000                      0.000         6.010
# 25%          2.750         0.100                      1.750        12.992
# 50%          3.500         0.250                      3.000        18.950
# 75%          4.250         0.400                      4.000        31.668
# max          5.000         0.400                      5.000        43.100

# %%
# checking categorical features
cat_features = data.select_dtypes(include='O').keys()
# display variabels
cat_features
# Out:
# Index([], dtype='object')

# %%
# b) Data visualizations
# Box and Whisker Plots of a few features

plt.rcParams["figure.figsize"] = [10, 6]
plt.rcParams["figure.autolayout"] = True

raw_plot = pd.DataFrame(data)
raw_plot.plot(kind='box', subplots=True, layout=(4,3), sharex=False, sharey=False)
plt.show()
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count

# %% [markdown]
# We can see the data skewed to high values in relative compactness, roof area, glazing area, and cooling load.

# %%
# create the stack bar chart of Heating and Cooling Load
fig, ax = plt.subplots()
ax.bar(np.arange(len(data['Heating Load'])), data['Heating Load'], label='Heating Load')

# add labels, title and legend
ax.set_xlabel('Number of Samples')
ax.set_ylabel('Energy Consumption (kWh)')
ax.set_title('bill')
ax.legend()

# show the plot
plt.show()

# %% [markdown]
# The data displays a cyclical pattern that may have resulted from the measurements taken on weekdays (with longer hours) and weekends.

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(12, 8))

# Flatten the axes array to simplify plotting
axes = axes.flatten()

# Loop through each feature and create a density plot
for i, feature in enumerate(raw_plot.columns):
    sns.kdeplot(raw_plot[feature], ax=axes[i], color='steelblue', fill=True)
    axes[i].set_title(feature)

# Adjust the layout and spacing of the subplots
fig.tight_layout()

plt.show()

# %% [markdown]
# The dataset seems to be complex as most of features exhibit non-Gaussian distributions, except for the Surface Area. There are several factors that could cause non-Gaussian distributions, including outliers, measurement errors, or the inherent characteristics of the building designs.

# %%
# correlation matrix between all pairs of attributes
corr_matrix = data.corr(method='pearson')

# Create a heatmap using seaborn
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_matrix, vmin=-1, vmax=1, annot=True, cmap="coolwarm", ax=ax)

plt.show()

# %% [markdown]
# According to the correlation matrix, the heating and cooling loads, as well as energy consumption, exhibit strong correlations with the overall height, orientation, and to some extent, the surface area. The orientation is considered to be an uncertain factor in building design due to limited choices compared to other variables and it plays a significant role in determining the energy efficiency of a building.

# %% [markdown]
# **3. Prepare Data**

# %%
# a) Data Cleaning
# summarize the number of unique values in each column
print(data.nunique())
# Out:
# Relative Compactness          12
# Surface Area                  12
# Roof Area                      4
# Overall Height                 2
# Orientation                    4
# Glazing Area                   4
# Glazing Area Distribution      6
# Heating Load                 586
# dtype: int64

# %%
# Identify columns with missing values and count the number of missing values
data.columns[data.isnull().any()]
print(data.isnull().sum())
# Out:
# Relative Compactness         0
# Surface Area                 0
# Roof Area                    0
# Overall Height               0
# Orientation                  0
# Glazing Area                 0
# Glazing Area Distribution    0
# Heating Load                 0
# dtype: int64

# %% [markdown]
# It is necessary to eliminate outliers in numerical data columns to improve the accuracy of training and validation processes. This can be done by determining the correlation between these columns and the target variable, identifying columns with low correlation, and then filtering out values that fall outside of the lower and upper bounds.

# %%
# calculate the correlation between numerical columns and target variables
corr_matrix = data.select_dtypes(include=np.number).corrwith(data['Heating Load']).sort_values(ascending=False)

# filter columns with low correlation
corr_threshold = 0.05
low_corr_columns = corr_matrix[corr_matrix.abs() < corr_threshold].index

# remove outliers from numerical columns with low correlation
for column in low_corr_columns:
    lower = data[column].quantile(0.01)
    upper = data[column].quantile(0.99)
    data[column] = data[column].clip(lower, upper)

# %%
# calculate the correlation between numerical columns and target variables
corr_matrix = data.select_dtypes(include=np.number).corrwith(data['Heating Load']).sort_values(ascending=False)

# filter columns with low correlation
corr_threshold = 0.05
low_corr_columns = corr_matrix[corr_matrix.abs() < corr_threshold].index

# remove outliers from numerical columns with low correlation
for column in low_corr_columns:
    lower = data[column].quantile(0.01)
    upper = data[column].quantile(0.99)
    data[column] = data[column].clip(lower, upper)

# %%
# b) Split-out dataset into train and validation sets

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=1)

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (576, 7) (576, 1) (192, 7) (192, 1)

# %%
# c) Data Transforms
# Standardize the dataset by rescaling the distribution of values

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.fit_transform(X_val)

# %% [markdown]
# **4. Evaluate Algorithms**

# %%
# a) Spot check algorithms using cross-validation technique
num_folds = 8
seed = 8

# Select 5 most popular linear and tree-based algorithms for evaluation
models = []
models.append(('LR', LinearRegression()))
models.append(('EN', ElasticNet()))
models.append(('RF', RandomForestRegressor()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('SVR', MultiOutputRegressor(SVR(gamma='auto'))))

# %%
# Neural Network algorithms
# create keras Sequential model
def baseline_model():
    model = Sequential()
    model.add(Dense(300, input_shape = (7, ), activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(Dense(200, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(Dense(100, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(Dense(1))
    # Compile model
    model.compile(optimizer = 'adam',
                loss = 'mean_squared_error',
                metrics=['mse'])
    return model

# Build model
model_NN = baseline_model()
models.append(('NN', model_NN))

# %%
# Define a callback for early stopping if the validation loss does not improve for 10 consecutive
# epochs (patience=10).
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
results = []
alg_names = []

# Initialize the KerasRegressor estimator with early stopping
estimator = KerasRegressor(model=model_NN, batch_size=128, verbose=1, callbacks=[early_stopping])

for name, model in models:
    kfold = KFold(n_splits=num_folds, random_state=seed, shuffle=True)

    # modify loop for NN
    if name != 'NN':
        cvs = cross_val_score(model, X_train, y_train, cv=kfold, scoring='neg_mean_squared_error')
    else:
        validation_data = (X_val, y_val)
        cvs = cross_val_score(estimator, X_train, y_train, cv=kfold, scoring='neg_mean_squared_error', fit_params={'validation_data': validation_data, 'epochs': 150})

    results.append(cvs)
    alg_names.append(name)
    output = "%s: %f (%f)" % (name, cvs.mean(), cvs.std())
    print(output)
# Out:
# LR: -8.213543 (1.870210)
# EN: -48.528127 (10.471758)
# c:\Users\Rasin bran 2\.pyenv\pyenv-win\versions\3.8.10\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\Users\Rasin bran 2\.pyenv\pyenv-win\versions\3.8.10\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\Users\Rasin bran 2\.pyenv\pyenv-win\versions\3.8.10\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\Users\Rasin bran 2\.pyenv\pyenv-win\versions\3.8.10\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\Users\Rasin bran 2\.pyenv\pyenv-win\versions\3.8.10\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\Users\Rasin bran 2\.pyenv\pyenv-win\versions\3.8.10\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\Users\Rasin bran 2\.pyenv\pyenv-win\versions\3.8.10\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\Users\Rasin bran 2\.pyenv\pyenv-win\versions\3.8.10\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# RF: -0.372258 (0.171265)
# KNN: -9.304752 (2.608518)
# SVR: -12.495847 (3.518934)
# INFO:tensorflow:Assets written to: C:\Users\RASINB~1\AppData\Local\Temp\tmpkvo5wr3f\assets
# INFO:tensorflow:Assets written to: C:\Users\RASINB~1\AppData\Local\Temp\tmpkvo5wr3f\assets
# Epoch 1/150
# 4/4 [==============================] - 1s 57ms/step - loss: 556.3560 - mse: 556.3560 - val_loss: 637.6707 - val_mse: 637.6707
# Epoch 2/150
# 4/4 [==============================] - 0s 14ms/step - loss: 518.6881 - mse: 518.6881 - val_loss: 628.9596 - val_mse: 628.9596
# Epoch 3/150
# 4/4 [==============================] - 0s 15ms/step - loss: 500.2209 - mse: 500.2209 - val_loss: 619.6514 - val_mse: 619.6514
# Epoch 4/150
# 4/4 [==============================] - 0s 15ms/step - loss: 487.0848 - mse: 487.0848 - val_loss: 610.2917 - val_mse: 610.2917
# Epoch 5/150
# 4/4 [==============================] - 0s 15ms/step - loss: 483.3331 - mse: 483.3331 - val_loss: 601.4405 - val_mse: 601.4405
# Epoch 6/150
# 4/4 [==============================] - 0s 14ms/step - loss: 479.7166 - mse: 479.7166 - val_loss: 593.0264 - val_mse: 593.0264
# Epoch 7/150
# 4/4 [==============================] - 0s 14ms/step - loss: 471.3793 - mse: 471.3793 - val_loss: 585.3830 - val_mse: 585.3830
# Epoch 8/150
# 4/4 [==============================] - 0s 14ms/step - loss: 469.2823 - mse: 469.2823 - val_loss: 578.8063 - val_mse: 578.8063
# Epoch 9/150
# 4/4 [==============================] - 0s 14ms/step - loss: 464.2703 - mse: 464.2703 - val_loss: 573.1517 - val_mse: 573.1517
# Epoch 10/150
# 4/4 [==============================] - 0s 15ms/step - loss: 463.7231 - mse: 463.7231 - val_loss: 567.6771 - val_mse: 567.6771
# Epoch 11/150
# 4/4 [==============================] - 0s 14ms/step - loss: 458.0777 - mse: 458.0777 - val_loss: 563.3326 - val_mse: 563.3326
# Epoch 12/150
# 4/4 [==============================] - 0s 15ms/step - loss: 453.7810 - mse: 453.7810 - val_loss: 558.9632 - val_mse: 558.9632
# Epoch 13/150
# 4/4 [==============================] - 0s 15ms/step - loss: 455.9494 - mse: 455.9494 - val_loss: 554.8566 - val_mse: 554.8566
# Epoch 14/150
# 4/4 [==============================] - 0s 15ms/step - loss: 449.5239 - mse: 449.5239 - val_loss: 551.1270 - val_mse: 551.1270
# Epoch 15/150
# 4/4 [==============================] - 0s 15ms/step - loss: 446.7751 - mse: 446.7751 - val_loss: 548.1397 - val_mse: 548.1397
# Epoch 16/150
# 4/4 [==============================] - 0s 15ms/step - loss: 441.9596 - mse: 441.9596 - val_loss: 544.6252 - val_mse: 544.6252
# Epoch 17/150
# 4/4 [==============================] - 0s 14ms/step - loss: 443.0400 - mse: 443.0400 - val_loss: 540.7706 - val_mse: 540.7706
# Epoch 18/150
# 4/4 [==============================] - 0s 14ms/step - loss: 435.2113 - mse: 435.2113 - val_loss: 537.1353 - val_mse: 537.1353
# Epoch 19/150
# 4/4 [==============================] - 0s 15ms/step - loss: 440.0580 - mse: 440.0580 - val_loss: 533.4050 - val_mse: 533.4050
# Epoch 20/150
# 4/4 [==============================] - 0s 14ms/step - loss: 429.1327 - mse: 429.1327 - val_loss: 529.3970 - val_mse: 529.3970
# Epoch 21/150
# 4/4 [==============================] - 0s 14ms/step - loss: 423.5588 - mse: 423.5588 - val_loss: 525.6835 - val_mse: 525.6835
# Epoch 22/150
# 4/4 [==============================] - 0s 14ms/step - loss: 426.9632 - mse: 426.9632 - val_loss: 521.7985 - val_mse: 521.7985
# Epoch 23/150
# 4/4 [==============================] - 0s 14ms/step - loss: 421.8531 - mse: 421.8531 - val_loss: 517.7888 - val_mse: 517.7888
# Epoch 24/150
# 4/4 [==============================] - 0s 15ms/step - loss: 413.5445 - mse: 413.5445 - val_loss: 511.6068 - val_mse: 511.6068
# Epoch 25/150
# 4/4 [==============================] - 0s 14ms/step - loss: 411.3944 - mse: 411.3944 - val_loss: 505.8739 - val_mse: 505.8739
# Epoch 26/150
# 4/4 [==============================] - 0s 14ms/step - loss: 397.5890 - mse: 397.5890 - val_loss: 500.2506 - val_mse: 500.2506
# Epoch 27/150
# 4/4 [==============================] - 0s 14ms/step - loss: 394.5056 - mse: 394.5056 - val_loss: 493.3065 - val_mse: 493.3065
# Epoch 28/150
# 4/4 [==============================] - 0s 14ms/step - loss: 390.6171 - mse: 390.6171 - val_loss: 486.4613 - val_mse: 486.4613
# Epoch 29/150
# 4/4 [==============================] - 0s 14ms/step - loss: 388.0589 - mse: 388.0589 - val_loss: 479.7145 - val_mse: 479.7145
# Epoch 30/150
# 4/4 [==============================] - 0s 14ms/step - loss: 389.9509 - mse: 389.9509 - val_loss: 472.2219 - val_mse: 472.2219
# Epoch 31/150
# 4/4 [==============================] - 0s 15ms/step - loss: 384.4075 - mse: 384.4075 - val_loss: 464.8546 - val_mse: 464.8546
# Epoch 32/150
# 4/4 [==============================] - 0s 14ms/step - loss: 372.3739 - mse: 372.3739 - val_loss: 457.6248 - val_mse: 457.6248
# Epoch 33/150
# 4/4 [==============================] - 0s 14ms/step - loss: 368.3300 - mse: 368.3300 - val_loss: 449.6416 - val_mse: 449.6416
# Epoch 34/150
# 4/4 [==============================] - 0s 14ms/step - loss: 366.6961 - mse: 366.6961 - val_loss: 440.7612 - val_mse: 440.7612
# Epoch 35/150
# 4/4 [==============================] - 0s 15ms/step - loss: 362.7355 - mse: 362.7355 - val_loss: 432.1200 - val_mse: 432.1200
# Epoch 36/150
# 4/4 [==============================] - 0s 15ms/step - loss: 354.4614 - mse: 354.4614 - val_loss: 425.2343 - val_mse: 425.2343
# Epoch 37/150
# 4/4 [==============================] - 0s 14ms/step - loss: 348.6790 - mse: 348.6790 - val_loss: 418.1888 - val_mse: 418.1888
# Epoch 38/150
# 4/4 [==============================] - 0s 14ms/step - loss: 339.8115 - mse: 339.8115 - val_loss: 411.4738 - val_mse: 411.4738
# Epoch 39/150
# 4/4 [==============================] - 0s 14ms/step - loss: 337.7397 - mse: 337.7397 - val_loss: 404.1772 - val_mse: 404.1772
# Epoch 40/150
# 4/4 [==============================] - 0s 15ms/step - loss: 330.8889 - mse: 330.8889 - val_loss: 397.7285 - val_mse: 397.7285
# Epoch 41/150
# 4/4 [==============================] - 0s 14ms/step - loss: 324.4151 - mse: 324.4151 - val_loss: 392.0181 - val_mse: 392.0181
# Epoch 42/150
# 4/4 [==============================] - 0s 15ms/step - loss: 310.4706 - mse: 310.4706 - val_loss: 384.2225 - val_mse: 384.2225
# Epoch 43/150
# 4/4 [==============================] - 0s 14ms/step - loss: 308.1280 - mse: 308.1280 - val_loss: 376.7772 - val_mse: 376.7772
# Epoch 44/150
# 4/4 [==============================] - 0s 14ms/step - loss: 296.3665 - mse: 296.3665 - val_loss: 367.4248 - val_mse: 367.4248
# Epoch 45/150
# 4/4 [==============================] - 0s 14ms/step - loss: 285.9357 - mse: 285.9357 - val_loss: 355.7325 - val_mse: 355.7325
# Epoch 46/150
# 4/4 [==============================] - 0s 14ms/step - loss: 291.1354 - mse: 291.1354 - val_loss: 344.5440 - val_mse: 344.5440
# Epoch 47/150
# 4/4 [==============================] - 0s 14ms/step - loss: 277.6525 - mse: 277.6525 - val_loss: 336.0117 - val_mse: 336.0117
# Epoch 48/150
# 4/4 [==============================] - 0s 14ms/step - loss: 276.3364 - mse: 276.3364 - val_loss: 327.1337 - val_mse: 327.1337
# Epoch 49/150
# 4/4 [==============================] - 0s 15ms/step - loss: 267.8687 - mse: 267.8687 - val_loss: 320.1505 - val_mse: 320.1505
# Epoch 50/150
# 4/4 [==============================] - 0s 14ms/step - loss: 252.1724 - mse: 252.1724 - val_loss: 315.0122 - val_mse: 315.0122
# Epoch 51/150
# 4/4 [==============================] - 0s 14ms/step - loss: 250.1985 - mse: 250.1985 - val_loss: 308.3314 - val_mse: 308.3314
# Epoch 52/150
# 4/4 [==============================] - 0s 14ms/step - loss: 239.9072 - mse: 239.9072 - val_loss: 299.1761 - val_mse: 299.1761
# Epoch 53/150
# 4/4 [==============================] - 0s 14ms/step - loss: 236.9065 - mse: 236.9065 - val_loss: 288.6722 - val_mse: 288.6722
# Epoch 54/150
# 4/4 [==============================] - 0s 14ms/step - loss: 231.5344 - mse: 231.5344 - val_loss: 277.9981 - val_mse: 277.9981
# Epoch 55/150
# 4/4 [==============================] - 0s 14ms/step - loss: 221.5262 - mse: 221.5262 - val_loss: 268.8384 - val_mse: 268.8384
# Epoch 56/150
# 4/4 [==============================] - 0s 14ms/step - loss: 211.2859 - mse: 211.2859 - val_loss: 260.0606 - val_mse: 260.0606
# Epoch 57/150
# 4/4 [==============================] - 0s 14ms/step - loss: 203.4176 - mse: 203.4176 - val_loss: 251.7076 - val_mse: 251.7076
# Epoch 58/150
# 4/4 [==============================] - 0s 15ms/step - loss: 197.8591 - mse: 197.8591 - val_loss: 242.4330 - val_mse: 242.4330
# Epoch 59/150
# 4/4 [==============================] - 0s 14ms/step - loss: 196.4481 - mse: 196.4481 - val_loss: 235.2576 - val_mse: 235.2576
# Epoch 60/150
# 4/4 [==============================] - 0s 15ms/step - loss: 186.6711 - mse: 186.6711 - val_loss: 227.8995 - val_mse: 227.8995
# Epoch 61/150
# 4/4 [==============================] - 0s 14ms/step - loss: 178.4742 - mse: 178.4742 - val_loss: 217.3236 - val_mse: 217.3236
# Epoch 62/150
# 4/4 [==============================] - 0s 15ms/step - loss: 165.3544 - mse: 165.3544 - val_loss: 206.2369 - val_mse: 206.2369
# Epoch 63/150
# 4/4 [==============================] - 0s 15ms/step - loss: 160.1558 - mse: 160.1558 - val_loss: 195.6134 - val_mse: 195.6134
# Epoch 64/150
# 4/4 [==============================] - 0s 15ms/step - loss: 159.2489 - mse: 159.2489 - val_loss: 184.8331 - val_mse: 184.8331
# Epoch 65/150
# 4/4 [==============================] - 0s 14ms/step - loss: 148.4221 - mse: 148.4221 - val_loss: 175.4674 - val_mse: 175.4674
# Epoch 66/150
# 4/4 [==============================] - 0s 14ms/step - loss: 141.1486 - mse: 141.1486 - val_loss: 166.2189 - val_mse: 166.2189
# Epoch 67/150
# 4/4 [==============================] - 0s 14ms/step - loss: 137.1658 - mse: 137.1658 - val_loss: 158.4179 - val_mse: 158.4179
# Epoch 68/150
# 4/4 [==============================] - 0s 15ms/step - loss: 130.4603 - mse: 130.4603 - val_loss: 151.9821 - val_mse: 151.9821
# Epoch 69/150
# 4/4 [==============================] - 0s 15ms/step - loss: 127.4403 - mse: 127.4403 - val_loss: 146.6840 - val_mse: 146.6840
# Epoch 70/150
# 4/4 [==============================] - 0s 14ms/step - loss: 123.0232 - mse: 123.0232 - val_loss: 141.9877 - val_mse: 141.9877
# Epoch 71/150
# 4/4 [==============================] - 0s 14ms/step - loss: 113.6015 - mse: 113.6015 - val_loss: 134.6782 - val_mse: 134.6782
# Epoch 72/150
# 4/4 [==============================] - 0s 14ms/step - loss: 114.6299 - mse: 114.6299 - val_loss: 128.6990 - val_mse: 128.6990
# Epoch 73/150
# 4/4 [==============================] - 0s 14ms/step - loss: 104.3011 - mse: 104.3011 - val_loss: 121.1664 - val_mse: 121.1664
# Epoch 74/150
# 4/4 [==============================] - 0s 15ms/step - loss: 102.2039 - mse: 102.2039 - val_loss: 114.3855 - val_mse: 114.3855
# Epoch 75/150
# 4/4 [==============================] - 0s 14ms/step - loss: 91.0495 - mse: 91.0495 - val_loss: 108.0884 - val_mse: 108.0884
# Epoch 76/150
# 4/4 [==============================] - 0s 15ms/step - loss: 90.0951 - mse: 90.0951 - val_loss: 102.1152 - val_mse: 102.1152
# Epoch 77/150
# 4/4 [==============================] - 0s 14ms/step - loss: 82.9936 - mse: 82.9936 - val_loss: 96.6914 - val_mse: 96.6914
# Epoch 78/150
# 4/4 [==============================] - 0s 15ms/step - loss: 83.9308 - mse: 83.9308 - val_loss: 91.7907 - val_mse: 91.7907
# Epoch 79/150
# 4/4 [==============================] - 0s 14ms/step - loss: 77.6397 - mse: 77.6397 - val_loss: 85.8552 - val_mse: 85.8552
# Epoch 80/150
# 4/4 [==============================] - 0s 15ms/step - loss: 75.3554 - mse: 75.3554 - val_loss: 80.2706 - val_mse: 80.2706
# Epoch 81/150
# 4/4 [==============================] - 0s 15ms/step - loss: 69.6569 - mse: 69.6569 - val_loss: 75.3464 - val_mse: 75.3464
# Epoch 82/150
# 4/4 [==============================] - 0s 14ms/step - loss: 64.7314 - mse: 64.7314 - val_loss: 71.1674 - val_mse: 71.1674
# Epoch 83/150
# 4/4 [==============================] - 0s 14ms/step - loss: 65.3528 - mse: 65.3528 - val_loss: 67.7248 - val_mse: 67.7248
# Epoch 84/150
# 4/4 [==============================] - 0s 15ms/step - loss: 59.8271 - mse: 59.8271 - val_loss: 63.4668 - val_mse: 63.4668
# Epoch 85/150
# 4/4 [==============================] - 0s 15ms/step - loss: 57.0625 - mse: 57.0625 - val_loss: 58.7619 - val_mse: 58.7619
# Epoch 86/150
# 4/4 [==============================] - 0s 17ms/step - loss: 57.3898 - mse: 57.3898 - val_loss: 55.2466 - val_mse: 55.2466
# Epoch 87/150
# 4/4 [==============================] - 0s 15ms/step - loss: 52.5146 - mse: 52.5146 - val_loss: 51.2393 - val_mse: 51.2393
# Epoch 88/150
# 4/4 [==============================] - 0s 14ms/step - loss: 49.5702 - mse: 49.5702 - val_loss: 47.8981 - val_mse: 47.8981
# Epoch 89/150
# 4/4 [==============================] - 0s 14ms/step - loss: 48.8662 - mse: 48.8662 - val_loss: 45.2487 - val_mse: 45.2487
# Epoch 90/150
# 4/4 [==============================] - 0s 15ms/step - loss: 43.6597 - mse: 43.6597 - val_loss: 43.1000 - val_mse: 43.1000
# Epoch 91/150
# 4/4 [==============================] - 0s 14ms/step - loss: 46.5535 - mse: 46.5535 - val_loss: 42.1182 - val_mse: 42.1182
# Epoch 92/150
# 4/4 [==============================] - 0s 14ms/step - loss: 44.7892 - mse: 44.7892 - val_loss: 40.7594 - val_mse: 40.7594
# Epoch 93/150
# 4/4 [==============================] - 0s 14ms/step - loss: 42.1539 - mse: 42.1539 - val_loss: 38.9474 - val_mse: 38.9474
# Epoch 94/150
# 4/4 [==============================] - 0s 15ms/step - loss: 38.0082 - mse: 38.0082 - val_loss: 36.5618 - val_mse: 36.5618
# Epoch 95/150
# 4/4 [==============================] - 0s 15ms/step - loss: 35.0078 - mse: 35.0078 - val_loss: 33.8584 - val_mse: 33.8584
# Epoch 96/150
# 4/4 [==============================] - 0s 15ms/step - loss: 33.5784 - mse: 33.5784 - val_loss: 31.8484 - val_mse: 31.8484
# Epoch 97/150
# 4/4 [==============================] - 0s 14ms/step - loss: 33.4272 - mse: 33.4272 - val_loss: 29.1760 - val_mse: 29.1760
# Epoch 98/150
# 4/4 [==============================] - 0s 15ms/step - loss: 36.7872 - mse: 36.7872 - val_loss: 27.6156 - val_mse: 27.6156
# Epoch 99/150
# 4/4 [==============================] - 0s 14ms/step - loss: 35.2016 - mse: 35.2016 - val_loss: 27.1025 - val_mse: 27.1025
# Epoch 100/150
# 4/4 [==============================] - 0s 14ms/step - loss: 32.4464 - mse: 32.4464 - val_loss: 26.6223 - val_mse: 26.6223
# Epoch 101/150
# 4/4 [==============================] - 0s 14ms/step - loss: 33.4689 - mse: 33.4689 - val_loss: 25.1456 - val_mse: 25.1456
# Epoch 102/150
# 4/4 [==============================] - 0s 15ms/step - loss: 32.5091 - mse: 32.5091 - val_loss: 23.1752 - val_mse: 23.1752
# Epoch 103/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.3918 - mse: 26.3918 - val_loss: 21.8400 - val_mse: 21.8400
# Epoch 104/150
# 4/4 [==============================] - 0s 15ms/step - loss: 30.6539 - mse: 30.6539 - val_loss: 20.5940 - val_mse: 20.5940
# Epoch 105/150
# 4/4 [==============================] - 0s 14ms/step - loss: 27.3941 - mse: 27.3941 - val_loss: 18.9721 - val_mse: 18.9721
# Epoch 106/150
# 4/4 [==============================] - 0s 14ms/step - loss: 29.3087 - mse: 29.3087 - val_loss: 17.4763 - val_mse: 17.4763
# Epoch 107/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.7329 - mse: 26.7329 - val_loss: 16.3076 - val_mse: 16.3076
# Epoch 108/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.8145 - mse: 26.8145 - val_loss: 15.2055 - val_mse: 15.2055
# Epoch 109/150
# 4/4 [==============================] - 0s 14ms/step - loss: 28.3393 - mse: 28.3393 - val_loss: 15.4989 - val_mse: 15.4989
# Epoch 110/150
# 4/4 [==============================] - 0s 14ms/step - loss: 27.3421 - mse: 27.3421 - val_loss: 15.9093 - val_mse: 15.9093
# Epoch 111/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.0546 - mse: 26.0546 - val_loss: 15.9224 - val_mse: 15.9224
# Epoch 112/150
# 4/4 [==============================] - 0s 14ms/step - loss: 24.9489 - mse: 24.9489 - val_loss: 16.2306 - val_mse: 16.2306
# Epoch 113/150
# 4/4 [==============================] - 0s 14ms/step - loss: 27.2649 - mse: 27.2649 - val_loss: 15.9448 - val_mse: 15.9448
# Epoch 114/150
# 4/4 [==============================] - 0s 15ms/step - loss: 24.6239 - mse: 24.6239 - val_loss: 15.7159 - val_mse: 15.7159
# Epoch 115/150
# 4/4 [==============================] - 0s 15ms/step - loss: 21.7751 - mse: 21.7751 - val_loss: 15.5852 - val_mse: 15.5852
# Epoch 116/150
# 4/4 [==============================] - 0s 14ms/step - loss: 24.4884 - mse: 24.4884 - val_loss: 14.9600 - val_mse: 14.9600
# Epoch 117/150
# 4/4 [==============================] - 0s 14ms/step - loss: 25.2923 - mse: 25.2923 - val_loss: 14.2814 - val_mse: 14.2814
# Epoch 118/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.0370 - mse: 26.0370 - val_loss: 14.0037 - val_mse: 14.0037
# Epoch 119/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.5607 - mse: 23.5607 - val_loss: 13.5855 - val_mse: 13.5855
# Epoch 120/150
# 4/4 [==============================] - 0s 15ms/step - loss: 22.0681 - mse: 22.0681 - val_loss: 12.8207 - val_mse: 12.8207
# Epoch 121/150
# 4/4 [==============================] - 0s 14ms/step - loss: 25.3846 - mse: 25.3846 - val_loss: 12.4327 - val_mse: 12.4327
# Epoch 122/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.2973 - mse: 23.2973 - val_loss: 11.8573 - val_mse: 11.8573
# Epoch 123/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.7316 - mse: 23.7316 - val_loss: 10.8153 - val_mse: 10.8153
# Epoch 124/150
# 4/4 [==============================] - 0s 15ms/step - loss: 22.5701 - mse: 22.5701 - val_loss: 10.4429 - val_mse: 10.4429
# Epoch 125/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.8737 - mse: 26.8737 - val_loss: 10.4411 - val_mse: 10.4411
# Epoch 126/150
# 4/4 [==============================] - 0s 14ms/step - loss: 25.8009 - mse: 25.8009 - val_loss: 10.7083 - val_mse: 10.7083
# Epoch 127/150
# 4/4 [==============================] - 0s 15ms/step - loss: 23.4414 - mse: 23.4414 - val_loss: 10.6963 - val_mse: 10.6963
# Epoch 128/150
# 4/4 [==============================] - 0s 14ms/step - loss: 24.2352 - mse: 24.2352 - val_loss: 10.4388 - val_mse: 10.4388
# Epoch 129/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.8534 - mse: 23.8534 - val_loss: 10.2995 - val_mse: 10.2995
# Epoch 130/150
# 4/4 [==============================] - 0s 15ms/step - loss: 21.3801 - mse: 21.3801 - val_loss: 10.3979 - val_mse: 10.3979
# Epoch 131/150
# 4/4 [==============================] - 0s 15ms/step - loss: 23.1516 - mse: 23.1516 - val_loss: 10.2147 - val_mse: 10.2147
# Epoch 132/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.8359 - mse: 23.8359 - val_loss: 9.8577 - val_mse: 9.8577
# Epoch 133/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.6400 - mse: 23.6400 - val_loss: 9.4250 - val_mse: 9.4250
# Epoch 134/150
# 4/4 [==============================] - 0s 15ms/step - loss: 21.5990 - mse: 21.5990 - val_loss: 9.0827 - val_mse: 9.0827
# Epoch 135/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.2093 - mse: 21.2093 - val_loss: 8.8004 - val_mse: 8.8004
# Epoch 136/150
# 4/4 [==============================] - 0s 14ms/step - loss: 20.3506 - mse: 20.3506 - val_loss: 9.0682 - val_mse: 9.0682
# Epoch 137/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.0617 - mse: 26.0617 - val_loss: 9.1735 - val_mse: 9.1735
# Epoch 138/150
# 4/4 [==============================] - 0s 14ms/step - loss: 19.9425 - mse: 19.9425 - val_loss: 9.1424 - val_mse: 9.1424
# Epoch 139/150
# 4/4 [==============================] - 0s 15ms/step - loss: 25.3868 - mse: 25.3868 - val_loss: 9.0507 - val_mse: 9.0507
# Epoch 140/150
# 4/4 [==============================] - 0s 14ms/step - loss: 22.8661 - mse: 22.8661 - val_loss: 8.7944 - val_mse: 8.7944
# Epoch 141/150
# 4/4 [==============================] - 0s 14ms/step - loss: 20.4848 - mse: 20.4848 - val_loss: 8.6657 - val_mse: 8.6657
# Epoch 142/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.8232 - mse: 21.8232 - val_loss: 8.7399 - val_mse: 8.7399
# Epoch 143/150
# 4/4 [==============================] - 0s 14ms/step - loss: 24.5115 - mse: 24.5115 - val_loss: 8.7843 - val_mse: 8.7843
# Epoch 144/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.6586 - mse: 21.6586 - val_loss: 8.8172 - val_mse: 8.8172
# Epoch 145/150
# 4/4 [==============================] - 0s 15ms/step - loss: 19.2593 - mse: 19.2593 - val_loss: 8.9587 - val_mse: 8.9587
# Epoch 146/150
# 4/4 [==============================] - 0s 15ms/step - loss: 17.7060 - mse: 17.7060 - val_loss: 8.8199 - val_mse: 8.8199
# Epoch 147/150
# 4/4 [==============================] - 0s 14ms/step - loss: 19.3303 - mse: 19.3303 - val_loss: 8.5485 - val_mse: 8.5485
# Epoch 148/150
# 4/4 [==============================] - 0s 15ms/step - loss: 19.1626 - mse: 19.1626 - val_loss: 8.2062 - val_mse: 8.2062
# Epoch 149/150
# 4/4 [==============================] - 0s 14ms/step - loss: 18.7589 - mse: 18.7589 - val_loss: 7.9346 - val_mse: 7.9346
# Epoch 150/150
# 4/4 [==============================] - 0s 14ms/step - loss: 19.2779 - mse: 19.2779 - val_loss: 7.7714 - val_mse: 7.7714
# 1/1 [==============================] - 0s 75ms/step
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# INFO:tensorflow:Assets written to: C:\Users\RASINB~1\AppData\Local\Temp\tmp1ozzhnj_\assets
# INFO:tensorflow:Assets written to: C:\Users\RASINB~1\AppData\Local\Temp\tmp1ozzhnj_\assets
# Epoch 1/150
# 4/4 [==============================] - 1s 54ms/step - loss: 574.1360 - mse: 574.1360 - val_loss: 637.8122 - val_mse: 637.8122
# Epoch 2/150
# 4/4 [==============================] - 0s 14ms/step - loss: 537.2029 - mse: 537.2029 - val_loss: 629.1540 - val_mse: 629.1540
# Epoch 3/150
# 4/4 [==============================] - 0s 14ms/step - loss: 519.1108 - mse: 519.1108 - val_loss: 620.2933 - val_mse: 620.2933
# Epoch 4/150
# 4/4 [==============================] - 0s 14ms/step - loss: 508.3862 - mse: 508.3862 - val_loss: 611.6216 - val_mse: 611.6216
# Epoch 5/150
# 4/4 [==============================] - 0s 15ms/step - loss: 502.2053 - mse: 502.2053 - val_loss: 602.9022 - val_mse: 602.9022
# Epoch 6/150
# 4/4 [==============================] - 0s 14ms/step - loss: 494.9630 - mse: 494.9630 - val_loss: 594.2739 - val_mse: 594.2739
# Epoch 7/150
# 4/4 [==============================] - 0s 14ms/step - loss: 490.3383 - mse: 490.3383 - val_loss: 586.2256 - val_mse: 586.2256
# Epoch 8/150
# 4/4 [==============================] - 0s 14ms/step - loss: 491.7404 - mse: 491.7404 - val_loss: 578.8467 - val_mse: 578.8467
# Epoch 9/150
# 4/4 [==============================] - 0s 15ms/step - loss: 480.3124 - mse: 480.3124 - val_loss: 572.1445 - val_mse: 572.1445
# Epoch 10/150
# 4/4 [==============================] - 0s 15ms/step - loss: 479.9962 - mse: 479.9962 - val_loss: 566.0693 - val_mse: 566.0693
# Epoch 11/150
# 4/4 [==============================] - 0s 15ms/step - loss: 473.3306 - mse: 473.3306 - val_loss: 560.7766 - val_mse: 560.7766
# Epoch 12/150
# 4/4 [==============================] - 0s 15ms/step - loss: 469.6613 - mse: 469.6613 - val_loss: 556.0323 - val_mse: 556.0323
# Epoch 13/150
# 4/4 [==============================] - 0s 15ms/step - loss: 473.3025 - mse: 473.3025 - val_loss: 551.8326 - val_mse: 551.8326
# Epoch 14/150
# 4/4 [==============================] - 0s 15ms/step - loss: 467.2867 - mse: 467.2867 - val_loss: 548.2879 - val_mse: 548.2879
# Epoch 15/150
# 4/4 [==============================] - 0s 15ms/step - loss: 463.9127 - mse: 463.9127 - val_loss: 544.2821 - val_mse: 544.2821
# Epoch 16/150
# 4/4 [==============================] - 0s 15ms/step - loss: 461.3161 - mse: 461.3161 - val_loss: 540.6798 - val_mse: 540.6798
# Epoch 17/150
# 4/4 [==============================] - 0s 14ms/step - loss: 458.3808 - mse: 458.3808 - val_loss: 536.8817 - val_mse: 536.8817
# Epoch 18/150
# 4/4 [==============================] - 0s 15ms/step - loss: 451.5217 - mse: 451.5217 - val_loss: 533.1844 - val_mse: 533.1844
# Epoch 19/150
# 4/4 [==============================] - 0s 15ms/step - loss: 445.2202 - mse: 445.2202 - val_loss: 529.4701 - val_mse: 529.4701
# Epoch 20/150
# 4/4 [==============================] - 0s 15ms/step - loss: 447.0089 - mse: 447.0089 - val_loss: 524.7755 - val_mse: 524.7755
# Epoch 21/150
# 4/4 [==============================] - 0s 15ms/step - loss: 441.1640 - mse: 441.1640 - val_loss: 521.0491 - val_mse: 521.0491
# Epoch 22/150
# 4/4 [==============================] - 0s 15ms/step - loss: 440.1809 - mse: 440.1809 - val_loss: 515.9476 - val_mse: 515.9476
# Epoch 23/150
# 4/4 [==============================] - 0s 14ms/step - loss: 436.2265 - mse: 436.2265 - val_loss: 511.0296 - val_mse: 511.0296
# Epoch 24/150
# 4/4 [==============================] - 0s 14ms/step - loss: 435.1892 - mse: 435.1892 - val_loss: 505.8004 - val_mse: 505.8004
# Epoch 25/150
# 4/4 [==============================] - 0s 14ms/step - loss: 427.0352 - mse: 427.0352 - val_loss: 500.3773 - val_mse: 500.3773
# Epoch 26/150
# 4/4 [==============================] - 0s 15ms/step - loss: 419.8097 - mse: 419.8097 - val_loss: 494.9115 - val_mse: 494.9115
# Epoch 27/150
# 4/4 [==============================] - 0s 14ms/step - loss: 419.1130 - mse: 419.1130 - val_loss: 488.1601 - val_mse: 488.1601
# Epoch 28/150
# 4/4 [==============================] - 0s 15ms/step - loss: 411.9031 - mse: 411.9031 - val_loss: 481.7323 - val_mse: 481.7323
# Epoch 29/150
# 4/4 [==============================] - 0s 17ms/step - loss: 405.4188 - mse: 405.4188 - val_loss: 475.7153 - val_mse: 475.7153
# Epoch 30/150
# 4/4 [==============================] - 0s 16ms/step - loss: 404.6006 - mse: 404.6006 - val_loss: 469.4144 - val_mse: 469.4144
# Epoch 31/150
# 4/4 [==============================] - 0s 15ms/step - loss: 398.8254 - mse: 398.8254 - val_loss: 463.7180 - val_mse: 463.7180
# Epoch 32/150
# 4/4 [==============================] - 0s 15ms/step - loss: 386.6938 - mse: 386.6938 - val_loss: 456.8076 - val_mse: 456.8076
# Epoch 33/150
# 4/4 [==============================] - 0s 15ms/step - loss: 385.4700 - mse: 385.4700 - val_loss: 449.6050 - val_mse: 449.6050
# Epoch 34/150
# 4/4 [==============================] - 0s 16ms/step - loss: 380.1748 - mse: 380.1748 - val_loss: 442.1452 - val_mse: 442.1452
# Epoch 35/150
# 4/4 [==============================] - 0s 15ms/step - loss: 371.0532 - mse: 371.0532 - val_loss: 434.0108 - val_mse: 434.0108
# Epoch 36/150
# 4/4 [==============================] - 0s 15ms/step - loss: 367.3560 - mse: 367.3560 - val_loss: 425.1248 - val_mse: 425.1248
# Epoch 37/150
# 4/4 [==============================] - 0s 15ms/step - loss: 363.1432 - mse: 363.1432 - val_loss: 416.0872 - val_mse: 416.0872
# Epoch 38/150
# 4/4 [==============================] - 0s 14ms/step - loss: 358.8826 - mse: 358.8826 - val_loss: 407.4948 - val_mse: 407.4948
# Epoch 39/150
# 4/4 [==============================] - 0s 15ms/step - loss: 352.9464 - mse: 352.9464 - val_loss: 399.7982 - val_mse: 399.7982
# Epoch 40/150
# 4/4 [==============================] - 0s 14ms/step - loss: 334.3637 - mse: 334.3637 - val_loss: 390.2890 - val_mse: 390.2890
# Epoch 41/150
# 4/4 [==============================] - 0s 15ms/step - loss: 337.8662 - mse: 337.8662 - val_loss: 381.6216 - val_mse: 381.6216
# Epoch 42/150
# 4/4 [==============================] - 0s 14ms/step - loss: 335.0247 - mse: 335.0247 - val_loss: 372.6311 - val_mse: 372.6311
# Epoch 43/150
# 4/4 [==============================] - 0s 14ms/step - loss: 326.6249 - mse: 326.6249 - val_loss: 364.9798 - val_mse: 364.9798
# Epoch 44/150
# 4/4 [==============================] - 0s 14ms/step - loss: 318.1370 - mse: 318.1370 - val_loss: 356.7846 - val_mse: 356.7846
# Epoch 45/150
# 4/4 [==============================] - 0s 14ms/step - loss: 310.8685 - mse: 310.8685 - val_loss: 349.1283 - val_mse: 349.1283
# Epoch 46/150
# 4/4 [==============================] - 0s 14ms/step - loss: 299.2007 - mse: 299.2007 - val_loss: 342.0009 - val_mse: 342.0009
# Epoch 47/150
# 4/4 [==============================] - 0s 14ms/step - loss: 296.0127 - mse: 296.0127 - val_loss: 334.3788 - val_mse: 334.3788
# Epoch 48/150
# 4/4 [==============================] - 0s 15ms/step - loss: 289.2838 - mse: 289.2838 - val_loss: 325.6954 - val_mse: 325.6954
# Epoch 49/150
# 4/4 [==============================] - 0s 16ms/step - loss: 273.3967 - mse: 273.3967 - val_loss: 318.4398 - val_mse: 318.4398
# Epoch 50/150
# 4/4 [==============================] - 0s 15ms/step - loss: 263.6655 - mse: 263.6655 - val_loss: 311.1707 - val_mse: 311.1707
# Epoch 51/150
# 4/4 [==============================] - 0s 15ms/step - loss: 264.8494 - mse: 264.8494 - val_loss: 305.0722 - val_mse: 305.0722
# Epoch 52/150
# 4/4 [==============================] - 0s 14ms/step - loss: 251.1488 - mse: 251.1488 - val_loss: 299.3388 - val_mse: 299.3388
# Epoch 53/150
# 4/4 [==============================] - 0s 15ms/step - loss: 251.0675 - mse: 251.0675 - val_loss: 293.1283 - val_mse: 293.1283
# Epoch 54/150
# 4/4 [==============================] - 0s 15ms/step - loss: 241.0442 - mse: 241.0442 - val_loss: 285.9567 - val_mse: 285.9567
# Epoch 55/150
# 4/4 [==============================] - 0s 14ms/step - loss: 237.4963 - mse: 237.4963 - val_loss: 278.8376 - val_mse: 278.8376
# Epoch 56/150
# 4/4 [==============================] - 0s 14ms/step - loss: 223.6116 - mse: 223.6116 - val_loss: 272.2493 - val_mse: 272.2493
# Epoch 57/150
# 4/4 [==============================] - 0s 14ms/step - loss: 214.4903 - mse: 214.4903 - val_loss: 264.9799 - val_mse: 264.9799
# Epoch 58/150
# 4/4 [==============================] - 0s 14ms/step - loss: 211.5146 - mse: 211.5146 - val_loss: 258.4727 - val_mse: 258.4727
# Epoch 59/150
# 4/4 [==============================] - 0s 15ms/step - loss: 193.8557 - mse: 193.8557 - val_loss: 251.9301 - val_mse: 251.9301
# Epoch 60/150
# 4/4 [==============================] - 0s 14ms/step - loss: 190.4207 - mse: 190.4207 - val_loss: 245.2330 - val_mse: 245.2330
# Epoch 61/150
# 4/4 [==============================] - 0s 15ms/step - loss: 183.4958 - mse: 183.4958 - val_loss: 240.5215 - val_mse: 240.5215
# Epoch 62/150
# 4/4 [==============================] - 0s 15ms/step - loss: 176.7811 - mse: 176.7811 - val_loss: 232.8983 - val_mse: 232.8983
# Epoch 63/150
# 4/4 [==============================] - 0s 14ms/step - loss: 171.8025 - mse: 171.8025 - val_loss: 223.9889 - val_mse: 223.9889
# Epoch 64/150
# 4/4 [==============================] - 0s 14ms/step - loss: 165.9265 - mse: 165.9265 - val_loss: 213.7580 - val_mse: 213.7580
# Epoch 65/150
# 4/4 [==============================] - 0s 14ms/step - loss: 158.9178 - mse: 158.9178 - val_loss: 201.5578 - val_mse: 201.5578
# Epoch 66/150
# 4/4 [==============================] - 0s 15ms/step - loss: 155.8373 - mse: 155.8373 - val_loss: 188.3861 - val_mse: 188.3861
# Epoch 67/150
# 4/4 [==============================] - 0s 15ms/step - loss: 140.4501 - mse: 140.4501 - val_loss: 177.2648 - val_mse: 177.2648
# Epoch 68/150
# 4/4 [==============================] - 0s 14ms/step - loss: 142.7911 - mse: 142.7911 - val_loss: 167.7365 - val_mse: 167.7365
# Epoch 69/150
# 4/4 [==============================] - 0s 14ms/step - loss: 133.5697 - mse: 133.5697 - val_loss: 158.7298 - val_mse: 158.7298
# Epoch 70/150
# 4/4 [==============================] - 0s 14ms/step - loss: 126.6682 - mse: 126.6682 - val_loss: 151.2822 - val_mse: 151.2822
# Epoch 71/150
# 4/4 [==============================] - 0s 15ms/step - loss: 119.4108 - mse: 119.4108 - val_loss: 145.0118 - val_mse: 145.0118
# Epoch 72/150
# 4/4 [==============================] - 0s 14ms/step - loss: 112.6093 - mse: 112.6093 - val_loss: 137.2011 - val_mse: 137.2011
# Epoch 73/150
# 4/4 [==============================] - 0s 14ms/step - loss: 107.6514 - mse: 107.6514 - val_loss: 130.4473 - val_mse: 130.4473
# Epoch 74/150
# 4/4 [==============================] - 0s 16ms/step - loss: 103.7284 - mse: 103.7284 - val_loss: 124.0028 - val_mse: 124.0028
# Epoch 75/150
# 4/4 [==============================] - 0s 15ms/step - loss: 99.3355 - mse: 99.3355 - val_loss: 117.9391 - val_mse: 117.9391
# Epoch 76/150
# 4/4 [==============================] - 0s 14ms/step - loss: 94.2671 - mse: 94.2671 - val_loss: 112.8298 - val_mse: 112.8298
# Epoch 77/150
# 4/4 [==============================] - 0s 15ms/step - loss: 91.2756 - mse: 91.2756 - val_loss: 108.8502 - val_mse: 108.8502
# Epoch 78/150
# 4/4 [==============================] - 0s 15ms/step - loss: 84.6123 - mse: 84.6123 - val_loss: 103.5702 - val_mse: 103.5702
# Epoch 79/150
# 4/4 [==============================] - 0s 15ms/step - loss: 82.0490 - mse: 82.0490 - val_loss: 98.0070 - val_mse: 98.0070
# Epoch 80/150
# 4/4 [==============================] - 0s 15ms/step - loss: 74.9078 - mse: 74.9078 - val_loss: 92.3969 - val_mse: 92.3969
# Epoch 81/150
# 4/4 [==============================] - 0s 15ms/step - loss: 77.6741 - mse: 77.6741 - val_loss: 87.4614 - val_mse: 87.4614
# Epoch 82/150
# 4/4 [==============================] - 0s 14ms/step - loss: 65.9383 - mse: 65.9383 - val_loss: 84.4175 - val_mse: 84.4175
# Epoch 83/150
# 4/4 [==============================] - 0s 14ms/step - loss: 66.5490 - mse: 66.5490 - val_loss: 80.5648 - val_mse: 80.5648
# Epoch 84/150
# 4/4 [==============================] - 0s 15ms/step - loss: 63.8231 - mse: 63.8231 - val_loss: 75.9612 - val_mse: 75.9612
# Epoch 85/150
# 4/4 [==============================] - 0s 15ms/step - loss: 58.2772 - mse: 58.2772 - val_loss: 70.7270 - val_mse: 70.7270
# Epoch 86/150
# 4/4 [==============================] - 0s 14ms/step - loss: 62.4955 - mse: 62.4955 - val_loss: 66.6898 - val_mse: 66.6898
# Epoch 87/150
# 4/4 [==============================] - 0s 15ms/step - loss: 54.8470 - mse: 54.8470 - val_loss: 64.4277 - val_mse: 64.4277
# Epoch 88/150
# 4/4 [==============================] - 0s 15ms/step - loss: 52.4996 - mse: 52.4996 - val_loss: 63.1072 - val_mse: 63.1072
# Epoch 89/150
# 4/4 [==============================] - 0s 16ms/step - loss: 46.9935 - mse: 46.9935 - val_loss: 61.0470 - val_mse: 61.0470
# Epoch 90/150
# 4/4 [==============================] - 0s 15ms/step - loss: 45.4717 - mse: 45.4717 - val_loss: 55.6519 - val_mse: 55.6519
# Epoch 91/150
# 4/4 [==============================] - 0s 15ms/step - loss: 45.7993 - mse: 45.7993 - val_loss: 51.1928 - val_mse: 51.1928
# Epoch 92/150
# 4/4 [==============================] - 0s 15ms/step - loss: 43.4965 - mse: 43.4965 - val_loss: 46.8135 - val_mse: 46.8135
# Epoch 93/150
# 4/4 [==============================] - 0s 15ms/step - loss: 45.2773 - mse: 45.2773 - val_loss: 42.5037 - val_mse: 42.5037
# Epoch 94/150
# 4/4 [==============================] - 0s 15ms/step - loss: 40.1942 - mse: 40.1942 - val_loss: 40.1639 - val_mse: 40.1639
# Epoch 95/150
# 4/4 [==============================] - 0s 14ms/step - loss: 40.0792 - mse: 40.0792 - val_loss: 38.6839 - val_mse: 38.6839
# Epoch 96/150
# 4/4 [==============================] - 0s 15ms/step - loss: 37.1529 - mse: 37.1529 - val_loss: 37.1387 - val_mse: 37.1387
# Epoch 97/150
# 4/4 [==============================] - 0s 15ms/step - loss: 35.9946 - mse: 35.9946 - val_loss: 34.5963 - val_mse: 34.5963
# Epoch 98/150
# 4/4 [==============================] - 0s 14ms/step - loss: 36.1257 - mse: 36.1257 - val_loss: 34.1014 - val_mse: 34.1014
# Epoch 99/150
# 4/4 [==============================] - 0s 14ms/step - loss: 32.5211 - mse: 32.5211 - val_loss: 33.1542 - val_mse: 33.1542
# Epoch 100/150
# 4/4 [==============================] - 0s 14ms/step - loss: 33.6510 - mse: 33.6510 - val_loss: 31.7760 - val_mse: 31.7760
# Epoch 101/150
# 4/4 [==============================] - 0s 14ms/step - loss: 31.4112 - mse: 31.4112 - val_loss: 29.5856 - val_mse: 29.5856
# Epoch 102/150
# 4/4 [==============================] - 0s 14ms/step - loss: 31.2566 - mse: 31.2566 - val_loss: 27.6529 - val_mse: 27.6529
# Epoch 103/150
# 4/4 [==============================] - 0s 14ms/step - loss: 31.7901 - mse: 31.7901 - val_loss: 26.7596 - val_mse: 26.7596
# Epoch 104/150
# 4/4 [==============================] - 0s 14ms/step - loss: 31.9143 - mse: 31.9143 - val_loss: 25.8537 - val_mse: 25.8537
# Epoch 105/150
# 4/4 [==============================] - 0s 14ms/step - loss: 32.2609 - mse: 32.2609 - val_loss: 24.7591 - val_mse: 24.7591
# Epoch 106/150
# 4/4 [==============================] - 0s 14ms/step - loss: 30.5902 - mse: 30.5902 - val_loss: 23.8678 - val_mse: 23.8678
# Epoch 107/150
# 4/4 [==============================] - 0s 16ms/step - loss: 26.9498 - mse: 26.9498 - val_loss: 21.9701 - val_mse: 21.9701
# Epoch 108/150
# 4/4 [==============================] - 0s 15ms/step - loss: 27.2054 - mse: 27.2054 - val_loss: 20.6722 - val_mse: 20.6722
# Epoch 109/150
# 4/4 [==============================] - 0s 14ms/step - loss: 27.5895 - mse: 27.5895 - val_loss: 19.9021 - val_mse: 19.9021
# Epoch 110/150
# 4/4 [==============================] - 0s 15ms/step - loss: 26.5276 - mse: 26.5276 - val_loss: 19.5799 - val_mse: 19.5799
# Epoch 111/150
# 4/4 [==============================] - 0s 14ms/step - loss: 25.3279 - mse: 25.3279 - val_loss: 18.9504 - val_mse: 18.9504
# Epoch 112/150
# 4/4 [==============================] - 0s 18ms/step - loss: 27.7545 - mse: 27.7545 - val_loss: 17.6335 - val_mse: 17.6335
# Epoch 113/150
# 4/4 [==============================] - 0s 15ms/step - loss: 24.1657 - mse: 24.1657 - val_loss: 15.7875 - val_mse: 15.7875
# Epoch 114/150
# 4/4 [==============================] - 0s 15ms/step - loss: 26.5196 - mse: 26.5196 - val_loss: 14.1767 - val_mse: 14.1767
# Epoch 115/150
# 4/4 [==============================] - 0s 15ms/step - loss: 27.0046 - mse: 27.0046 - val_loss: 13.1280 - val_mse: 13.1280
# Epoch 116/150
# 4/4 [==============================] - 0s 14ms/step - loss: 22.6107 - mse: 22.6107 - val_loss: 12.7182 - val_mse: 12.7182
# Epoch 117/150
# 4/4 [==============================] - 0s 14ms/step - loss: 22.9304 - mse: 22.9304 - val_loss: 12.6239 - val_mse: 12.6239
# Epoch 118/150
# 4/4 [==============================] - 0s 14ms/step - loss: 24.9055 - mse: 24.9055 - val_loss: 12.4643 - val_mse: 12.4643
# Epoch 119/150
# 4/4 [==============================] - 0s 15ms/step - loss: 26.4787 - mse: 26.4787 - val_loss: 12.6359 - val_mse: 12.6359
# Epoch 120/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.8488 - mse: 26.8488 - val_loss: 13.0578 - val_mse: 13.0578
# Epoch 121/150
# 4/4 [==============================] - 0s 15ms/step - loss: 22.7775 - mse: 22.7775 - val_loss: 13.3057 - val_mse: 13.3057
# Epoch 122/150
# 4/4 [==============================] - 0s 17ms/step - loss: 23.7918 - mse: 23.7918 - val_loss: 13.4307 - val_mse: 13.4307
# Epoch 123/150
# 4/4 [==============================] - 0s 15ms/step - loss: 21.7927 - mse: 21.7927 - val_loss: 12.7210 - val_mse: 12.7210
# Epoch 124/150
# 4/4 [==============================] - 0s 15ms/step - loss: 22.1626 - mse: 22.1626 - val_loss: 12.1279 - val_mse: 12.1279
# Epoch 125/150
# 4/4 [==============================] - 0s 15ms/step - loss: 26.4232 - mse: 26.4232 - val_loss: 12.1383 - val_mse: 12.1383
# Epoch 126/150
# 4/4 [==============================] - 0s 15ms/step - loss: 25.8348 - mse: 25.8348 - val_loss: 12.0371 - val_mse: 12.0371
# Epoch 127/150
# 4/4 [==============================] - 0s 15ms/step - loss: 21.0729 - mse: 21.0729 - val_loss: 11.5563 - val_mse: 11.5563
# Epoch 128/150
# 4/4 [==============================] - 0s 15ms/step - loss: 23.2641 - mse: 23.2641 - val_loss: 11.3905 - val_mse: 11.3905
# Epoch 129/150
# ...
# Epoch 35/150
# 4/4 [==============================] - 0s 14ms/step - loss: 363.3196 - mse: 363.3196 - val_loss: 439.6605 - val_mse: 439.6605
# Epoch 36/150
# 4/4 [==============================] - 0s 14ms/step - loss: 350.2234 - mse: 350.2234 - val_loss: 432.3144 - val_mse: 432.3144
# Epoch 37/150
# 4/4 [==============================] - 0s 15ms/step - loss: 349.3822 - mse: 349.3822 - val_loss: 427.1618 - val_mse: 427.1618
# Epoch 38/150
# 4/4 [==============================] - 0s 14ms/step - loss: 340.0616 - mse: 340.0616 - val_loss: 421.2297 - val_mse: 421.2297
# Epoch 39/150
# 4/4 [==============================] - 0s 14ms/step - loss: 339.4559 - mse: 339.4559 - val_loss: 417.4515 - val_mse: 417.4515
# Epoch 40/150
# 4/4 [==============================] - 0s 15ms/step - loss: 322.7211 - mse: 322.7211 - val_loss: 412.1514 - val_mse: 412.1514
# Epoch 41/150
# 4/4 [==============================] - 0s 14ms/step - loss: 322.5115 - mse: 322.5115 - val_loss: 405.7913 - val_mse: 405.7913
# Epoch 42/150
# 4/4 [==============================] - 0s 14ms/step - loss: 317.3694 - mse: 317.3694 - val_loss: 399.8888 - val_mse: 399.8888
# Epoch 43/150
# 4/4 [==============================] - 0s 13ms/step - loss: 308.2816 - mse: 308.2816 - val_loss: 393.3078 - val_mse: 393.3078
# Epoch 44/150
# 4/4 [==============================] - 0s 14ms/step - loss: 299.8768 - mse: 299.8768 - val_loss: 386.1151 - val_mse: 386.1151
# Epoch 45/150
# 4/4 [==============================] - 0s 14ms/step - loss: 294.6664 - mse: 294.6664 - val_loss: 378.3472 - val_mse: 378.3472
# Epoch 46/150
# 4/4 [==============================] - 0s 14ms/step - loss: 285.8124 - mse: 285.8124 - val_loss: 371.1635 - val_mse: 371.1635
# Epoch 47/150
# 4/4 [==============================] - 0s 14ms/step - loss: 279.0404 - mse: 279.0404 - val_loss: 363.6554 - val_mse: 363.6554
# Epoch 48/150
# 4/4 [==============================] - 0s 14ms/step - loss: 270.1476 - mse: 270.1476 - val_loss: 352.2795 - val_mse: 352.2795
# Epoch 49/150
# 4/4 [==============================] - 0s 15ms/step - loss: 266.8534 - mse: 266.8534 - val_loss: 342.8543 - val_mse: 342.8543
# Epoch 50/150
# 4/4 [==============================] - 0s 14ms/step - loss: 257.6823 - mse: 257.6823 - val_loss: 334.1775 - val_mse: 334.1775
# Epoch 51/150
# 4/4 [==============================] - 0s 14ms/step - loss: 250.5887 - mse: 250.5887 - val_loss: 325.5235 - val_mse: 325.5235
# Epoch 52/150
# 4/4 [==============================] - 0s 14ms/step - loss: 238.9695 - mse: 238.9695 - val_loss: 317.9892 - val_mse: 317.9892
# Epoch 53/150
# 4/4 [==============================] - 0s 14ms/step - loss: 235.6684 - mse: 235.6684 - val_loss: 309.9186 - val_mse: 309.9186
# Epoch 54/150
# 4/4 [==============================] - 0s 14ms/step - loss: 228.5793 - mse: 228.5793 - val_loss: 301.3587 - val_mse: 301.3587
# Epoch 55/150
# 4/4 [==============================] - 0s 14ms/step - loss: 217.2538 - mse: 217.2538 - val_loss: 294.2614 - val_mse: 294.2614
# Epoch 56/150
# 4/4 [==============================] - 0s 14ms/step - loss: 213.7120 - mse: 213.7120 - val_loss: 286.4274 - val_mse: 286.4274
# Epoch 57/150
# 4/4 [==============================] - 0s 14ms/step - loss: 203.9504 - mse: 203.9504 - val_loss: 276.1072 - val_mse: 276.1072
# Epoch 58/150
# 4/4 [==============================] - 0s 15ms/step - loss: 193.9331 - mse: 193.9331 - val_loss: 263.1159 - val_mse: 263.1159
# Epoch 59/150
# 4/4 [==============================] - 0s 16ms/step - loss: 187.4068 - mse: 187.4068 - val_loss: 250.7896 - val_mse: 250.7896
# Epoch 60/150
# 4/4 [==============================] - 0s 14ms/step - loss: 181.2737 - mse: 181.2737 - val_loss: 241.7477 - val_mse: 241.7477
# Epoch 61/150
# 4/4 [==============================] - 0s 14ms/step - loss: 174.6599 - mse: 174.6599 - val_loss: 232.6448 - val_mse: 232.6448
# Epoch 62/150
# 4/4 [==============================] - 0s 15ms/step - loss: 168.7720 - mse: 168.7720 - val_loss: 222.5802 - val_mse: 222.5802
# Epoch 63/150
# 4/4 [==============================] - 0s 15ms/step - loss: 157.5641 - mse: 157.5641 - val_loss: 213.5371 - val_mse: 213.5371
# Epoch 64/150
# 4/4 [==============================] - 0s 14ms/step - loss: 152.0104 - mse: 152.0104 - val_loss: 205.7831 - val_mse: 205.7831
# Epoch 65/150
# 4/4 [==============================] - 0s 14ms/step - loss: 149.4590 - mse: 149.4590 - val_loss: 198.8263 - val_mse: 198.8263
# Epoch 66/150
# 4/4 [==============================] - 0s 14ms/step - loss: 144.2777 - mse: 144.2777 - val_loss: 191.7589 - val_mse: 191.7589
# Epoch 67/150
# 4/4 [==============================] - 0s 15ms/step - loss: 135.0682 - mse: 135.0682 - val_loss: 185.8215 - val_mse: 185.8215
# Epoch 68/150
# 4/4 [==============================] - 0s 14ms/step - loss: 129.4509 - mse: 129.4509 - val_loss: 180.6210 - val_mse: 180.6210
# Epoch 69/150
# 4/4 [==============================] - 0s 15ms/step - loss: 122.5503 - mse: 122.5503 - val_loss: 174.3943 - val_mse: 174.3943
# Epoch 70/150
# 4/4 [==============================] - 0s 14ms/step - loss: 114.9905 - mse: 114.9905 - val_loss: 168.4350 - val_mse: 168.4350
# Epoch 71/150
# 4/4 [==============================] - 0s 14ms/step - loss: 116.8267 - mse: 116.8267 - val_loss: 163.5605 - val_mse: 163.5605
# Epoch 72/150
# 4/4 [==============================] - 0s 14ms/step - loss: 119.2602 - mse: 119.2602 - val_loss: 157.9944 - val_mse: 157.9944
# Epoch 73/150
# 4/4 [==============================] - 0s 14ms/step - loss: 99.0203 - mse: 99.0203 - val_loss: 151.5453 - val_mse: 151.5453
# Epoch 74/150
# 4/4 [==============================] - 0s 14ms/step - loss: 96.4951 - mse: 96.4951 - val_loss: 142.4137 - val_mse: 142.4137
# Epoch 75/150
# 4/4 [==============================] - 0s 14ms/step - loss: 94.9704 - mse: 94.9704 - val_loss: 133.3971 - val_mse: 133.3971
# Epoch 76/150
# 4/4 [==============================] - 0s 14ms/step - loss: 90.3061 - mse: 90.3061 - val_loss: 124.9444 - val_mse: 124.9444
# Epoch 77/150
# 4/4 [==============================] - 0s 14ms/step - loss: 84.6723 - mse: 84.6723 - val_loss: 116.7933 - val_mse: 116.7933
# Epoch 78/150
# 4/4 [==============================] - 0s 14ms/step - loss: 78.3618 - mse: 78.3618 - val_loss: 110.9057 - val_mse: 110.9057
# Epoch 79/150
# 4/4 [==============================] - 0s 13ms/step - loss: 75.5672 - mse: 75.5672 - val_loss: 105.8694 - val_mse: 105.8694
# Epoch 80/150
# 4/4 [==============================] - 0s 14ms/step - loss: 75.0153 - mse: 75.0153 - val_loss: 96.9686 - val_mse: 96.9686
# Epoch 81/150
# 4/4 [==============================] - 0s 14ms/step - loss: 72.0970 - mse: 72.0970 - val_loss: 89.0836 - val_mse: 89.0836
# Epoch 82/150
# 4/4 [==============================] - 0s 14ms/step - loss: 68.5061 - mse: 68.5061 - val_loss: 82.4264 - val_mse: 82.4264
# Epoch 83/150
# 4/4 [==============================] - 0s 14ms/step - loss: 62.8681 - mse: 62.8681 - val_loss: 77.1993 - val_mse: 77.1993
# Epoch 84/150
# 4/4 [==============================] - 0s 14ms/step - loss: 60.6772 - mse: 60.6772 - val_loss: 73.2293 - val_mse: 73.2293
# Epoch 85/150
# 4/4 [==============================] - 0s 14ms/step - loss: 52.8145 - mse: 52.8145 - val_loss: 70.1219 - val_mse: 70.1219
# Epoch 86/150
# 4/4 [==============================] - 0s 14ms/step - loss: 55.9469 - mse: 55.9469 - val_loss: 68.8963 - val_mse: 68.8963
# Epoch 87/150
# 4/4 [==============================] - 0s 14ms/step - loss: 54.4906 - mse: 54.4906 - val_loss: 66.3206 - val_mse: 66.3206
# Epoch 88/150
# 4/4 [==============================] - 0s 14ms/step - loss: 48.5560 - mse: 48.5560 - val_loss: 61.4382 - val_mse: 61.4382
# Epoch 89/150
# 4/4 [==============================] - 0s 14ms/step - loss: 48.1433 - mse: 48.1433 - val_loss: 56.2776 - val_mse: 56.2776
# Epoch 90/150
# 4/4 [==============================] - 0s 15ms/step - loss: 45.3591 - mse: 45.3591 - val_loss: 52.9271 - val_mse: 52.9271
# Epoch 91/150
# 4/4 [==============================] - 0s 14ms/step - loss: 42.4136 - mse: 42.4136 - val_loss: 51.2563 - val_mse: 51.2563
# Epoch 92/150
# 4/4 [==============================] - 0s 13ms/step - loss: 41.6116 - mse: 41.6116 - val_loss: 49.3244 - val_mse: 49.3244
# Epoch 93/150
# 4/4 [==============================] - 0s 14ms/step - loss: 41.9157 - mse: 41.9157 - val_loss: 45.7576 - val_mse: 45.7576
# Epoch 94/150
# 4/4 [==============================] - 0s 14ms/step - loss: 43.6168 - mse: 43.6168 - val_loss: 41.8977 - val_mse: 41.8977
# Epoch 95/150
# 4/4 [==============================] - 0s 14ms/step - loss: 39.7507 - mse: 39.7507 - val_loss: 38.2329 - val_mse: 38.2329
# Epoch 96/150
# 4/4 [==============================] - 0s 14ms/step - loss: 36.8032 - mse: 36.8032 - val_loss: 35.1848 - val_mse: 35.1848
# Epoch 97/150
# 4/4 [==============================] - 0s 15ms/step - loss: 32.6419 - mse: 32.6419 - val_loss: 33.2057 - val_mse: 33.2057
# Epoch 98/150
# 4/4 [==============================] - 0s 14ms/step - loss: 33.9219 - mse: 33.9219 - val_loss: 32.0888 - val_mse: 32.0888
# Epoch 99/150
# 4/4 [==============================] - 0s 14ms/step - loss: 30.5446 - mse: 30.5446 - val_loss: 30.2278 - val_mse: 30.2278
# Epoch 100/150
# 4/4 [==============================] - 0s 14ms/step - loss: 30.6956 - mse: 30.6956 - val_loss: 28.8072 - val_mse: 28.8072
# Epoch 101/150
# 4/4 [==============================] - 0s 14ms/step - loss: 33.2696 - mse: 33.2696 - val_loss: 26.2384 - val_mse: 26.2384
# Epoch 102/150
# 4/4 [==============================] - 0s 14ms/step - loss: 32.8042 - mse: 32.8042 - val_loss: 22.9393 - val_mse: 22.9393
# Epoch 103/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.4304 - mse: 26.4304 - val_loss: 20.3286 - val_mse: 20.3286
# Epoch 104/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.1730 - mse: 26.1730 - val_loss: 19.1754 - val_mse: 19.1754
# Epoch 105/150
# 4/4 [==============================] - 0s 14ms/step - loss: 25.8803 - mse: 25.8803 - val_loss: 18.2177 - val_mse: 18.2177
# Epoch 106/150
# 4/4 [==============================] - 0s 14ms/step - loss: 26.4623 - mse: 26.4623 - val_loss: 17.9445 - val_mse: 17.9445
# Epoch 107/150
# 4/4 [==============================] - 0s 14ms/step - loss: 28.1493 - mse: 28.1493 - val_loss: 17.8925 - val_mse: 17.8925
# Epoch 108/150
# 4/4 [==============================] - 0s 17ms/step - loss: 27.9893 - mse: 27.9893 - val_loss: 16.9469 - val_mse: 16.9469
# Epoch 109/150
# 4/4 [==============================] - 0s 14ms/step - loss: 29.3954 - mse: 29.3954 - val_loss: 15.8495 - val_mse: 15.8495
# Epoch 110/150
# 4/4 [==============================] - 0s 14ms/step - loss: 24.1376 - mse: 24.1376 - val_loss: 15.3400 - val_mse: 15.3400
# Epoch 111/150
# 4/4 [==============================] - 0s 14ms/step - loss: 27.9384 - mse: 27.9384 - val_loss: 14.8166 - val_mse: 14.8166
# Epoch 112/150
# 4/4 [==============================] - 0s 14ms/step - loss: 22.9318 - mse: 22.9318 - val_loss: 14.5840 - val_mse: 14.5840
# Epoch 113/150
# 4/4 [==============================] - 0s 14ms/step - loss: 25.6154 - mse: 25.6154 - val_loss: 14.7739 - val_mse: 14.7739
# Epoch 114/150
# 4/4 [==============================] - 0s 14ms/step - loss: 24.8555 - mse: 24.8555 - val_loss: 15.7436 - val_mse: 15.7436
# Epoch 115/150
# 4/4 [==============================] - 0s 14ms/step - loss: 25.7315 - mse: 25.7315 - val_loss: 15.7790 - val_mse: 15.7790
# Epoch 116/150
# 4/4 [==============================] - 0s 15ms/step - loss: 28.9833 - mse: 28.9833 - val_loss: 15.0577 - val_mse: 15.0577
# Epoch 117/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.2618 - mse: 23.2618 - val_loss: 14.1176 - val_mse: 14.1176
# Epoch 118/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.9241 - mse: 23.9241 - val_loss: 13.6195 - val_mse: 13.6195
# Epoch 119/150
# 4/4 [==============================] - 0s 14ms/step - loss: 24.0014 - mse: 24.0014 - val_loss: 13.4664 - val_mse: 13.4664
# Epoch 120/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.7101 - mse: 21.7101 - val_loss: 12.9813 - val_mse: 12.9813
# Epoch 121/150
# 4/4 [==============================] - 0s 14ms/step - loss: 25.5039 - mse: 25.5039 - val_loss: 12.8491 - val_mse: 12.8491
# Epoch 122/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.4840 - mse: 23.4840 - val_loss: 13.0486 - val_mse: 13.0486
# Epoch 123/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.8656 - mse: 21.8656 - val_loss: 13.0521 - val_mse: 13.0521
# Epoch 124/150
# 4/4 [==============================] - 0s 14ms/step - loss: 24.1246 - mse: 24.1246 - val_loss: 12.7706 - val_mse: 12.7706
# Epoch 125/150
# 4/4 [==============================] - 0s 14ms/step - loss: 22.3443 - mse: 22.3443 - val_loss: 12.3938 - val_mse: 12.3938
# Epoch 126/150
# 4/4 [==============================] - 0s 14ms/step - loss: 20.1397 - mse: 20.1397 - val_loss: 12.1763 - val_mse: 12.1763
# Epoch 127/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.5941 - mse: 21.5941 - val_loss: 11.9436 - val_mse: 11.9436
# Epoch 128/150
# 4/4 [==============================] - 0s 14ms/step - loss: 22.8172 - mse: 22.8172 - val_loss: 11.6869 - val_mse: 11.6869
# Epoch 129/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.6818 - mse: 21.6818 - val_loss: 11.7521 - val_mse: 11.7521
# Epoch 130/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.1015 - mse: 21.1015 - val_loss: 11.8220 - val_mse: 11.8220
# Epoch 131/150
# 4/4 [==============================] - 0s 13ms/step - loss: 21.5319 - mse: 21.5319 - val_loss: 11.9564 - val_mse: 11.9564
# Epoch 132/150
# 4/4 [==============================] - 0s 14ms/step - loss: 19.8582 - mse: 19.8582 - val_loss: 11.4597 - val_mse: 11.4597
# Epoch 133/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.8463 - mse: 21.8463 - val_loss: 10.9031 - val_mse: 10.9031
# Epoch 134/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.3120 - mse: 23.3120 - val_loss: 10.2181 - val_mse: 10.2181
# Epoch 135/150
# 4/4 [==============================] - 0s 14ms/step - loss: 22.8788 - mse: 22.8788 - val_loss: 9.8360 - val_mse: 9.8360
# Epoch 136/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.9294 - mse: 21.9294 - val_loss: 9.6055 - val_mse: 9.6055
# Epoch 137/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.3213 - mse: 21.3213 - val_loss: 9.6258 - val_mse: 9.6258
# Epoch 138/150
# 4/4 [==============================] - 0s 14ms/step - loss: 22.0886 - mse: 22.0886 - val_loss: 10.0531 - val_mse: 10.0531
# Epoch 139/150
# 4/4 [==============================] - 0s 14ms/step - loss: 22.3389 - mse: 22.3389 - val_loss: 10.3146 - val_mse: 10.3146
# Epoch 140/150
# 4/4 [==============================] - 0s 15ms/step - loss: 21.7829 - mse: 21.7829 - val_loss: 10.4397 - val_mse: 10.4397
# Epoch 141/150
# 4/4 [==============================] - 0s 15ms/step - loss: 20.1837 - mse: 20.1837 - val_loss: 10.4181 - val_mse: 10.4181
# Epoch 142/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.7012 - mse: 23.7012 - val_loss: 10.0948 - val_mse: 10.0948
# Epoch 143/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.1808 - mse: 21.1808 - val_loss: 9.8116 - val_mse: 9.8116
# Epoch 144/150
# 4/4 [==============================] - 0s 14ms/step - loss: 20.9090 - mse: 20.9090 - val_loss: 9.4639 - val_mse: 9.4639
# Epoch 145/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.8125 - mse: 21.8125 - val_loss: 9.3424 - val_mse: 9.3424
# Epoch 146/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.9482 - mse: 21.9482 - val_loss: 9.3998 - val_mse: 9.3998
# Epoch 147/150
# 4/4 [==============================] - 0s 16ms/step - loss: 23.4419 - mse: 23.4419 - val_loss: 9.6298 - val_mse: 9.6298
# Epoch 148/150
# 4/4 [==============================] - 0s 14ms/step - loss: 18.9719 - mse: 18.9719 - val_loss: 9.8689 - val_mse: 9.8689
# Epoch 149/150
# 4/4 [==============================] - 0s 14ms/step - loss: 23.0704 - mse: 23.0704 - val_loss: 10.1774 - val_mse: 10.1774
# Epoch 150/150
# 4/4 [==============================] - 0s 14ms/step - loss: 21.5481 - mse: 21.5481 - val_loss: 10.2685 - val_mse: 10.2685
# 1/1 [==============================] - 0s 78ms/step
# NN: -7.853207 (2.119068)

# %%
# Plot learning curve of NN model
history = model_NN.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=500, batch_size=128, callbacks=[early_stopping])

plt.figure(figsize = (10, 5))
plt.plot(history.history['loss'], label = 'training')
plt.plot(history.history['val_loss'], label = 'testing')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Learning curve of the NN model')
plt.legend()
# Out:
# Epoch 1/500
# 5/5 [==============================] - 1s 46ms/step - loss: 559.8362 - mse: 559.8362 - val_loss: 635.3430 - val_mse: 635.3430
# Epoch 2/500
# 5/5 [==============================] - 0s 12ms/step - loss: 522.2365 - mse: 522.2365 - val_loss: 624.6725 - val_mse: 624.6725
# Epoch 3/500
# 5/5 [==============================] - 0s 12ms/step - loss: 507.3412 - mse: 507.3412 - val_loss: 614.8991 - val_mse: 614.8991
# Epoch 4/500
# 5/5 [==============================] - 0s 11ms/step - loss: 493.5118 - mse: 493.5118 - val_loss: 605.0456 - val_mse: 605.0456
# Epoch 5/500
# 5/5 [==============================] - 0s 11ms/step - loss: 491.3497 - mse: 491.3497 - val_loss: 595.0359 - val_mse: 595.0359
# Epoch 6/500
# 5/5 [==============================] - 0s 11ms/step - loss: 478.7591 - mse: 478.7591 - val_loss: 585.7885 - val_mse: 585.7885
# Epoch 7/500
# 5/5 [==============================] - 0s 11ms/step - loss: 476.6585 - mse: 476.6585 - val_loss: 577.9932 - val_mse: 577.9932
# Epoch 8/500
# 5/5 [==============================] - 0s 11ms/step - loss: 474.6450 - mse: 474.6450 - val_loss: 570.9363 - val_mse: 570.9363
# Epoch 9/500
# 5/5 [==============================] - 0s 11ms/step - loss: 464.4616 - mse: 464.4616 - val_loss: 563.9113 - val_mse: 563.9113
# Epoch 10/500
# 5/5 [==============================] - 0s 12ms/step - loss: 468.1439 - mse: 468.1439 - val_loss: 557.8162 - val_mse: 557.8162
# Epoch 11/500
# 5/5 [==============================] - 0s 11ms/step - loss: 461.3889 - mse: 461.3889 - val_loss: 552.7097 - val_mse: 552.7097
# Epoch 12/500
# 5/5 [==============================] - 0s 11ms/step - loss: 461.8601 - mse: 461.8601 - val_loss: 546.9571 - val_mse: 546.9571
# Epoch 13/500
# 5/5 [==============================] - 0s 11ms/step - loss: 452.2601 - mse: 452.2601 - val_loss: 539.8819 - val_mse: 539.8819
# Epoch 14/500
# 5/5 [==============================] - 0s 11ms/step - loss: 447.7211 - mse: 447.7211 - val_loss: 533.0029 - val_mse: 533.0029
# Epoch 15/500
# 5/5 [==============================] - 0s 11ms/step - loss: 448.1110 - mse: 448.1110 - val_loss: 527.2475 - val_mse: 527.2475
# Epoch 16/500
# 5/5 [==============================] - 0s 11ms/step - loss: 435.7963 - mse: 435.7963 - val_loss: 521.7125 - val_mse: 521.7125
# Epoch 17/500
# 5/5 [==============================] - 0s 11ms/step - loss: 437.6807 - mse: 437.6807 - val_loss: 517.2119 - val_mse: 517.2119
# Epoch 18/500
# 5/5 [==============================] - 0s 11ms/step - loss: 430.2708 - mse: 430.2708 - val_loss: 512.4495 - val_mse: 512.4495
# Epoch 19/500
# 5/5 [==============================] - 0s 11ms/step - loss: 429.8414 - mse: 429.8414 - val_loss: 507.6039 - val_mse: 507.6039
# Epoch 20/500
# 5/5 [==============================] - 0s 11ms/step - loss: 422.2318 - mse: 422.2318 - val_loss: 502.1476 - val_mse: 502.1476
# Epoch 21/500
# 5/5 [==============================] - 0s 11ms/step - loss: 418.2211 - mse: 418.2211 - val_loss: 496.1223 - val_mse: 496.1223
# Epoch 22/500
# 5/5 [==============================] - 0s 11ms/step - loss: 412.4266 - mse: 412.4266 - val_loss: 489.5958 - val_mse: 489.5958
# Epoch 23/500
# 5/5 [==============================] - 0s 11ms/step - loss: 405.3193 - mse: 405.3193 - val_loss: 481.9567 - val_mse: 481.9567
# Epoch 24/500
# 5/5 [==============================] - 0s 11ms/step - loss: 401.0211 - mse: 401.0211 - val_loss: 475.2105 - val_mse: 475.2105
# Epoch 25/500
# 5/5 [==============================] - 0s 11ms/step - loss: 392.1344 - mse: 392.1344 - val_loss: 466.1794 - val_mse: 466.1794
# Epoch 26/500
# 5/5 [==============================] - 0s 11ms/step - loss: 385.8965 - mse: 385.8965 - val_loss: 455.8085 - val_mse: 455.8085
# Epoch 27/500
# 5/5 [==============================] - 0s 12ms/step - loss: 380.5563 - mse: 380.5563 - val_loss: 448.6988 - val_mse: 448.6988
# Epoch 28/500
# 5/5 [==============================] - 0s 11ms/step - loss: 370.8493 - mse: 370.8493 - val_loss: 441.0963 - val_mse: 441.0963
# Epoch 29/500
# 5/5 [==============================] - 0s 12ms/step - loss: 370.1682 - mse: 370.1682 - val_loss: 433.0379 - val_mse: 433.0379
# Epoch 30/500
# 5/5 [==============================] - 0s 11ms/step - loss: 354.3845 - mse: 354.3845 - val_loss: 425.1793 - val_mse: 425.1793
# Epoch 31/500
# 5/5 [==============================] - 0s 11ms/step - loss: 347.9082 - mse: 347.9082 - val_loss: 414.8477 - val_mse: 414.8477
# Epoch 32/500
# 5/5 [==============================] - 0s 12ms/step - loss: 343.5216 - mse: 343.5216 - val_loss: 404.4989 - val_mse: 404.4989
# Epoch 33/500
# 5/5 [==============================] - 0s 11ms/step - loss: 328.7850 - mse: 328.7850 - val_loss: 394.5716 - val_mse: 394.5716
# Epoch 34/500
# 5/5 [==============================] - 0s 11ms/step - loss: 325.2279 - mse: 325.2279 - val_loss: 384.8883 - val_mse: 384.8883
# Epoch 35/500
# 5/5 [==============================] - 0s 11ms/step - loss: 317.4430 - mse: 317.4430 - val_loss: 376.5602 - val_mse: 376.5602
# Epoch 36/500
# 5/5 [==============================] - 0s 11ms/step - loss: 304.8216 - mse: 304.8216 - val_loss: 368.5492 - val_mse: 368.5492
# Epoch 37/500
# 5/5 [==============================] - 0s 11ms/step - loss: 300.4464 - mse: 300.4464 - val_loss: 361.1864 - val_mse: 361.1864
# Epoch 38/500
# 5/5 [==============================] - 0s 11ms/step - loss: 288.7164 - mse: 288.7164 - val_loss: 352.3864 - val_mse: 352.3864
# Epoch 39/500
# 5/5 [==============================] - 0s 11ms/step - loss: 282.7140 - mse: 282.7140 - val_loss: 345.9329 - val_mse: 345.9329
# Epoch 40/500
# 5/5 [==============================] - 0s 11ms/step - loss: 270.9328 - mse: 270.9328 - val_loss: 336.8064 - val_mse: 336.8064
# Epoch 41/500
# 5/5 [==============================] - 0s 11ms/step - loss: 259.3675 - mse: 259.3675 - val_loss: 323.2551 - val_mse: 323.2551
# Epoch 42/500
# 5/5 [==============================] - 0s 11ms/step - loss: 252.0397 - mse: 252.0397 - val_loss: 311.8888 - val_mse: 311.8888
# Epoch 43/500
# 5/5 [==============================] - 0s 12ms/step - loss: 244.1860 - mse: 244.1860 - val_loss: 300.8839 - val_mse: 300.8839
# Epoch 44/500
# 5/5 [==============================] - 0s 12ms/step - loss: 232.1684 - mse: 232.1684 - val_loss: 290.0852 - val_mse: 290.0852
# Epoch 45/500
# 5/5 [==============================] - 0s 11ms/step - loss: 228.6717 - mse: 228.6717 - val_loss: 278.2650 - val_mse: 278.2650
# Epoch 46/500
# 5/5 [==============================] - 0s 12ms/step - loss: 218.8042 - mse: 218.8042 - val_loss: 266.3737 - val_mse: 266.3737
# Epoch 47/500
# 5/5 [==============================] - 0s 11ms/step - loss: 208.7407 - mse: 208.7407 - val_loss: 255.8894 - val_mse: 255.8894
# Epoch 48/500
# 5/5 [==============================] - 0s 11ms/step - loss: 194.8555 - mse: 194.8555 - val_loss: 246.8515 - val_mse: 246.8515
# Epoch 49/500
# 5/5 [==============================] - 0s 11ms/step - loss: 183.4478 - mse: 183.4478 - val_loss: 237.3100 - val_mse: 237.3100
# Epoch 50/500
# 5/5 [==============================] - 0s 11ms/step - loss: 181.0765 - mse: 181.0765 - val_loss: 225.6774 - val_mse: 225.6774
# Epoch 51/500
# 5/5 [==============================] - 0s 11ms/step - loss: 176.3858 - mse: 176.3858 - val_loss: 214.3123 - val_mse: 214.3123
# Epoch 52/500
# 5/5 [==============================] - 0s 11ms/step - loss: 162.9736 - mse: 162.9736 - val_loss: 205.3550 - val_mse: 205.3550
# Epoch 53/500
# 5/5 [==============================] - 0s 11ms/step - loss: 153.9240 - mse: 153.9240 - val_loss: 194.3419 - val_mse: 194.3419
# Epoch 54/500
# 5/5 [==============================] - 0s 11ms/step - loss: 142.9944 - mse: 142.9944 - val_loss: 182.5917 - val_mse: 182.5917
# Epoch 55/500
# 5/5 [==============================] - 0s 12ms/step - loss: 137.2882 - mse: 137.2882 - val_loss: 170.8777 - val_mse: 170.8777
# Epoch 56/500
# 5/5 [==============================] - 0s 11ms/step - loss: 127.5564 - mse: 127.5564 - val_loss: 159.3221 - val_mse: 159.3221
# Epoch 57/500
# 5/5 [==============================] - 0s 11ms/step - loss: 127.5970 - mse: 127.5970 - val_loss: 150.8597 - val_mse: 150.8597
# Epoch 58/500
# 5/5 [==============================] - 0s 11ms/step - loss: 118.8597 - mse: 118.8597 - val_loss: 141.9436 - val_mse: 141.9436
# Epoch 59/500
# 5/5 [==============================] - 0s 11ms/step - loss: 112.6021 - mse: 112.6021 - val_loss: 130.1349 - val_mse: 130.1349
# Epoch 60/500
# 5/5 [==============================] - 0s 12ms/step - loss: 104.1105 - mse: 104.1105 - val_loss: 118.0115 - val_mse: 118.0115
# Epoch 61/500
# 5/5 [==============================] - 0s 12ms/step - loss: 98.0459 - mse: 98.0459 - val_loss: 110.4949 - val_mse: 110.4949
# Epoch 62/500
# 5/5 [==============================] - 0s 12ms/step - loss: 92.3252 - mse: 92.3252 - val_loss: 105.3768 - val_mse: 105.3768
# Epoch 63/500
# 5/5 [==============================] - 0s 11ms/step - loss: 86.6110 - mse: 86.6110 - val_loss: 100.6420 - val_mse: 100.6420
# Epoch 64/500
# 5/5 [==============================] - 0s 11ms/step - loss: 85.6497 - mse: 85.6497 - val_loss: 98.3114 - val_mse: 98.3114
# Epoch 65/500
# 5/5 [==============================] - 0s 11ms/step - loss: 73.6786 - mse: 73.6786 - val_loss: 92.8406 - val_mse: 92.8406
# Epoch 66/500
# 5/5 [==============================] - 0s 11ms/step - loss: 71.5601 - mse: 71.5601 - val_loss: 86.9359 - val_mse: 86.9359
# Epoch 67/500
# 5/5 [==============================] - 0s 11ms/step - loss: 69.8560 - mse: 69.8560 - val_loss: 81.7007 - val_mse: 81.7007
# Epoch 68/500
# 5/5 [==============================] - 0s 11ms/step - loss: 64.5557 - mse: 64.5557 - val_loss: 75.2671 - val_mse: 75.2671
# Epoch 69/500
# 5/5 [==============================] - 0s 12ms/step - loss: 54.2062 - mse: 54.2062 - val_loss: 69.6691 - val_mse: 69.6691
# Epoch 70/500
# 5/5 [==============================] - 0s 11ms/step - loss: 54.5011 - mse: 54.5011 - val_loss: 66.4268 - val_mse: 66.4268
# Epoch 71/500
# 5/5 [==============================] - 0s 12ms/step - loss: 50.4343 - mse: 50.4343 - val_loss: 60.6153 - val_mse: 60.6153
# Epoch 72/500
# 5/5 [==============================] - 0s 12ms/step - loss: 49.2314 - mse: 49.2314 - val_loss: 54.6399 - val_mse: 54.6399
# Epoch 73/500
# 5/5 [==============================] - 0s 12ms/step - loss: 47.0225 - mse: 47.0225 - val_loss: 50.4598 - val_mse: 50.4598
# Epoch 74/500
# 5/5 [==============================] - 0s 11ms/step - loss: 42.1320 - mse: 42.1320 - val_loss: 46.2576 - val_mse: 46.2576
# Epoch 75/500
# 5/5 [==============================] - 0s 11ms/step - loss: 45.4240 - mse: 45.4240 - val_loss: 45.2439 - val_mse: 45.2439
# Epoch 76/500
# 5/5 [==============================] - 0s 11ms/step - loss: 41.2269 - mse: 41.2269 - val_loss: 43.5314 - val_mse: 43.5314
# Epoch 77/500
# 5/5 [==============================] - 0s 12ms/step - loss: 37.0758 - mse: 37.0758 - val_loss: 37.9444 - val_mse: 37.9444
# Epoch 78/500
# 5/5 [==============================] - 0s 12ms/step - loss: 35.9179 - mse: 35.9179 - val_loss: 33.4312 - val_mse: 33.4312
# Epoch 79/500
# 5/5 [==============================] - 0s 11ms/step - loss: 36.4128 - mse: 36.4128 - val_loss: 30.0836 - val_mse: 30.0836
# Epoch 80/500
# 5/5 [==============================] - 0s 11ms/step - loss: 30.2907 - mse: 30.2907 - val_loss: 27.5071 - val_mse: 27.5071
# Epoch 81/500
# 5/5 [==============================] - 0s 11ms/step - loss: 34.2826 - mse: 34.2826 - val_loss: 25.9469 - val_mse: 25.9469
# Epoch 82/500
# 5/5 [==============================] - 0s 11ms/step - loss: 32.6671 - mse: 32.6671 - val_loss: 24.6534 - val_mse: 24.6534
# Epoch 83/500
# 5/5 [==============================] - 0s 11ms/step - loss: 31.3427 - mse: 31.3427 - val_loss: 23.6340 - val_mse: 23.6340
# Epoch 84/500
# 5/5 [==============================] - 0s 11ms/step - loss: 29.9774 - mse: 29.9774 - val_loss: 23.3471 - val_mse: 23.3471
# Epoch 85/500
# 5/5 [==============================] - 0s 11ms/step - loss: 28.4596 - mse: 28.4596 - val_loss: 21.9851 - val_mse: 21.9851
# Epoch 86/500
# 5/5 [==============================] - 0s 11ms/step - loss: 28.8991 - mse: 28.8991 - val_loss: 20.6551 - val_mse: 20.6551
# Epoch 87/500
# 5/5 [==============================] - 0s 12ms/step - loss: 28.0989 - mse: 28.0989 - val_loss: 19.3780 - val_mse: 19.3780
# Epoch 88/500
# 5/5 [==============================] - 0s 12ms/step - loss: 26.6608 - mse: 26.6608 - val_loss: 17.5116 - val_mse: 17.5116
# Epoch 89/500
# 5/5 [==============================] - 0s 12ms/step - loss: 30.0282 - mse: 30.0282 - val_loss: 16.2724 - val_mse: 16.2724
# Epoch 90/500
# 5/5 [==============================] - 0s 11ms/step - loss: 23.7979 - mse: 23.7979 - val_loss: 16.0531 - val_mse: 16.0531
# Epoch 91/500
# 5/5 [==============================] - 0s 12ms/step - loss: 22.5260 - mse: 22.5260 - val_loss: 15.4754 - val_mse: 15.4754
# Epoch 92/500
# 5/5 [==============================] - 0s 11ms/step - loss: 28.0977 - mse: 28.0977 - val_loss: 15.1545 - val_mse: 15.1545
# Epoch 93/500
# 5/5 [==============================] - 0s 12ms/step - loss: 25.5508 - mse: 25.5508 - val_loss: 15.3686 - val_mse: 15.3686
# Epoch 94/500
# 5/5 [==============================] - 0s 11ms/step - loss: 25.3513 - mse: 25.3513 - val_loss: 15.3093 - val_mse: 15.3093
# Epoch 95/500
# 5/5 [==============================] - 0s 13ms/step - loss: 25.4849 - mse: 25.4849 - val_loss: 14.6444 - val_mse: 14.6444
# Epoch 96/500
# 5/5 [==============================] - 0s 11ms/step - loss: 26.7352 - mse: 26.7352 - val_loss: 13.5119 - val_mse: 13.5119
# Epoch 97/500
# 5/5 [==============================] - 0s 11ms/step - loss: 26.1743 - mse: 26.1743 - val_loss: 12.4827 - val_mse: 12.4827
# Epoch 98/500
# 5/5 [==============================] - 0s 11ms/step - loss: 23.4631 - mse: 23.4631 - val_loss: 11.6922 - val_mse: 11.6922
# Epoch 99/500
# 5/5 [==============================] - 0s 11ms/step - loss: 22.0477 - mse: 22.0477 - val_loss: 10.9655 - val_mse: 10.9655
# Epoch 100/500
# 5/5 [==============================] - 0s 11ms/step - loss: 23.5919 - mse: 23.5919 - val_loss: 10.4656 - val_mse: 10.4656
# Epoch 101/500
# 5/5 [==============================] - 0s 11ms/step - loss: 21.1677 - mse: 21.1677 - val_loss: 10.2799 - val_mse: 10.2799
# Epoch 102/500
# 5/5 [==============================] - 0s 11ms/step - loss: 22.4339 - mse: 22.4339 - val_loss: 10.5331 - val_mse: 10.5331
# Epoch 103/500
# 5/5 [==============================] - 0s 12ms/step - loss: 22.8777 - mse: 22.8777 - val_loss: 10.9277 - val_mse: 10.9277
# Epoch 104/500
# 5/5 [==============================] - 0s 12ms/step - loss: 25.9898 - mse: 25.9898 - val_loss: 11.3550 - val_mse: 11.3550
# Epoch 105/500
# 5/5 [==============================] - 0s 11ms/step - loss: 21.9758 - mse: 21.9758 - val_loss: 11.1848 - val_mse: 11.1848
# Epoch 106/500
# 5/5 [==============================] - 0s 11ms/step - loss: 24.4463 - mse: 24.4463 - val_loss: 10.9194 - val_mse: 10.9194
# Epoch 107/500
# 5/5 [==============================] - 0s 11ms/step - loss: 23.8248 - mse: 23.8248 - val_loss: 10.6371 - val_mse: 10.6371
# Epoch 108/500
# 5/5 [==============================] - 0s 11ms/step - loss: 22.0691 - mse: 22.0691 - val_loss: 10.0003 - val_mse: 10.0003
# Epoch 109/500
# 5/5 [==============================] - 0s 11ms/step - loss: 25.7646 - mse: 25.7646 - val_loss: 9.7020 - val_mse: 9.7020
# Epoch 110/500
# 5/5 [==============================] - 0s 11ms/step - loss: 21.1657 - mse: 21.1657 - val_loss: 9.5739 - val_mse: 9.5739
# Epoch 111/500
# 5/5 [==============================] - 0s 11ms/step - loss: 22.6728 - mse: 22.6728 - val_loss: 9.2509 - val_mse: 9.2509
# Epoch 112/500
# 5/5 [==============================] - 0s 12ms/step - loss: 23.1217 - mse: 23.1217 - val_loss: 9.1586 - val_mse: 9.1586
# Epoch 113/500
# 5/5 [==============================] - 0s 11ms/step - loss: 22.2664 - mse: 22.2664 - val_loss: 9.4783 - val_mse: 9.4783
# Epoch 114/500
# 5/5 [==============================] - 0s 11ms/step - loss: 23.5914 - mse: 23.5914 - val_loss: 10.1019 - val_mse: 10.1019
# Epoch 115/500
# 5/5 [==============================] - 0s 11ms/step - loss: 24.1457 - mse: 24.1457 - val_loss: 10.4023 - val_mse: 10.4023
# Epoch 116/500
# 5/5 [==============================] - 0s 11ms/step - loss: 22.0657 - mse: 22.0657 - val_loss: 10.2921 - val_mse: 10.2921
# Epoch 117/500
# 5/5 [==============================] - 0s 11ms/step - loss: 21.9081 - mse: 21.9081 - val_loss: 9.4787 - val_mse: 9.4787
# Epoch 118/500
# 5/5 [==============================] - 0s 12ms/step - loss: 24.5313 - mse: 24.5313 - val_loss: 8.7918 - val_mse: 8.7918
# Epoch 119/500
# 5/5 [==============================] - 0s 11ms/step - loss: 22.6108 - mse: 22.6108 - val_loss: 8.8825 - val_mse: 8.8825
# Epoch 120/500
# 5/5 [==============================] - 0s 12ms/step - loss: 22.2890 - mse: 22.2890 - val_loss: 8.8957 - val_mse: 8.8957
# Epoch 121/500
# 5/5 [==============================] - 0s 11ms/step - loss: 21.0323 - mse: 21.0323 - val_loss: 9.1112 - val_mse: 9.1112
# Epoch 122/500
# 5/5 [==============================] - 0s 11ms/step - loss: 20.9255 - mse: 20.9255 - val_loss: 9.9865 - val_mse: 9.9865
# Epoch 123/500
# 5/5 [==============================] - 0s 11ms/step - loss: 19.0239 - mse: 19.0239 - val_loss: 10.0673 - val_mse: 10.0673
# Epoch 124/500
# 5/5 [==============================] - 0s 11ms/step - loss: 24.9660 - mse: 24.9660 - val_loss: 9.4576 - val_mse: 9.4576
# Epoch 125/500
# 5/5 [==============================] - 0s 11ms/step - loss: 22.9096 - mse: 22.9096 - val_loss: 8.3811 - val_mse: 8.3811
# Epoch 126/500
# 5/5 [==============================] - 0s 11ms/step - loss: 22.3391 - mse: 22.3391 - val_loss: 8.3938 - val_mse: 8.3938
# Epoch 127/500
# 5/5 [==============================] - 0s 11ms/step - loss: 19.1065 - mse: 19.1065 - val_loss: 9.3089 - val_mse: 9.3089
# Epoch 128/500
# 5/5 [==============================] - 0s 11ms/step - loss: 19.5615 - mse: 19.5615 - val_loss: 9.2790 - val_mse: 9.2790
# Epoch 129/500
# 5/5 [==============================] - 0s 12ms/step - loss: 21.9517 - mse: 21.9517 - val_loss: 8.8406 - val_mse: 8.8406
# Epoch 130/500
# 5/5 [==============================] - 0s 11ms/step - loss: 20.9010 - mse: 20.9010 - val_loss: 8.8283 - val_mse: 8.8283
# Epoch 131/500
# 5/5 [==============================] - 0s 11ms/step - loss: 21.0317 - mse: 21.0317 - val_loss: 8.7782 - val_mse: 8.7782
# Epoch 132/500
# 5/5 [==============================] - 0s 12ms/step - loss: 21.9702 - mse: 21.9702 - val_loss: 8.6580 - val_mse: 8.6580
# Epoch 133/500
# 5/5 [==============================] - 0s 11ms/step - loss: 22.1073 - mse: 22.1073 - val_loss: 8.7041 - val_mse: 8.7041
# Epoch 134/500
# 5/5 [==============================] - 0s 11ms/step - loss: 20.6899 - mse: 20.6899 - val_loss: 9.1539 - val_mse: 9.1539
# Epoch 135/500
# 5/5 [==============================] - 0s 11ms/step - loss: 23.3780 - mse: 23.3780 - val_loss: 8.7332 - val_mse: 8.7332

# %%
# b) Compare algorithms and the NN model
# Distribution of accuracy values calculated across 8 cross-validation folds.
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot()
plt.boxplot(results)
ax.set_xticklabels(alg_names)
plt.ylabel("MSE")
plt.show()

# %% [markdown]
# The Random Forest algorithm demonstrated superior performance compared to the other five machine learning algorithms and the neural network model.

# %% [markdown]
# In a regression problem, it is common to use the mean error as a measure of validation. This is done by first calculating the mean absolute error (MAE) of the test data with the mean of dataset, and then calculating the MAE of the test data with the predicted data.

# %%
# Evaluate performance of Random Forest algorithm on validation data
model_RF = RandomForestRegressor()
model_RF.fit(X_train, y_train)
y_pred_RF = model_RF.predict(X_val)
mae_pred_RF = mean_absolute_error(y_val, y_pred_RF)
print("Mean Absolute Error of predicted data: ", mae_pred_RF)
# Out:
# Mean Absolute Error of predicted data:  0.375170833333333
# C:\Users\Rasin bran 2\AppData\Local\Temp\ipykernel_36516\3872500001.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_RF.fit(X_train, y_train)

# %%
# Evaluate performance of NN algorithm on validation data
model_NN.fit(X_train, y_train)
y_pred_NN = model_NN.predict(X_val)
print(y_pred_NN.shape)
mae_pred_NN = mean_absolute_error(y_val, y_pred_NN)
print("Mean Absolute Error of predicted data: ", mae_pred_NN)
# Out:
# 18/18 [==============================] - 0s 5ms/step - loss: 22.5167 - mse: 22.5167
# 6/6 [==============================] - 0s 2ms/step
# (192, 1)
# Mean Absolute Error of predicted data:  2.0763323688507076

# %%
# Define baseline mean_absolute_error of y_val in the data set
y_mean = np.mean(y)
y_mean = np.array([y_mean]*len(y_val))
mae_ori = mean_absolute_error(y_val, y_mean)
print("Mean Absolute Error of original data: ", mae_ori)
# Out:
# Mean Absolute Error of original data:  9.156708306206598

# %% [markdown]
# The resulting MAE values show that Random Forest looks better than neural network model in prediction performance. For the sake of simplicity, I selected Random Forest as the surrogate model for the multi-objective optimization process.

# %% [markdown]
# **5. Finalize Model**

# %%
# a) Get best model parameters
model_params = model_RF.get_params()

# Print the model's parameters
print(model_params)
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %%
fig, ax = plt.subplots(figsize=(10, 5))

# Plot the actual and predicted heating load
ax.bar(np.arange(len(y_val)), y_val.iloc[:, 0], label='Actual heating load', color='orange')
ax.scatter(np.arange(len(y_pred_RF)), y_pred_RF, label='Predicted data', color='red')
ax.set_ylabel('Heating Load')
ax.legend()

# Show the plot
plt.show()

# %%
# b) Save model for later use
# save the model to disk
filename = 'finalized_model_multivariate.sav'
dump(model_RF, open(filename, 'wb'))

# %% [markdown]
# **6. Conclusions**

# %% [markdown]
# - Exploratory data analysis indicates that most input variables exhibit non-Gaussian distribution.
#
# - Based on our evaluation of five machine learning algorithms and a neural network model, we selected Random Forest as the surrogate model for multi-objective optimization due to its high score in cross validation and low Mean Squared Error values.
#
# - The Mean Absolute Error values suggest that the prediction accuracy is generally good, although the ElasticNet algorithm may require further refinement.
#
# - The results indicate that the performance of the Keras Sequential neural network model is comparable to that of other machine learning algorithms, and further hyperparameter tuning may improve its predictive accuracy.
